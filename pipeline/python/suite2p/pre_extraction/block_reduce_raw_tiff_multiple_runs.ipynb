# %%
import matplotlib.pyplot as plt
# %matplotlib inline
import os,glob,sys
import re

import numpy as np
from natsort import natsorted

#sys.path.insert(0, '/n/coxfs01/cechavarria/repos/suite2p')
sys.path.insert(0, '/home/julianarhee/Repositories/suite2p')

from scipy import ndimage
from suite2p.io.utils import get_tif_list, list_files #list_tifs

import scipy.io
from skimage.external.tifffile import imread, TiffFile, imsave
from skimage.measure import block_reduce

def findOccurrences(s, ch):
    return [i for i, letter in enumerate(s) if letter == ch]

def block_mean_stack(stack0, ds_block):
    im0 = block_reduce(stack0[0,:,:],ds_block) 
    print(im0.shape)
    stack1 = np.zeros((stack0.shape[0],im0.shape[0],im0.shape[1]))
    for i in range(0,stack0.shape[0]):
        stack1[i,:,:] = block_reduce(stack0[i,:,:],ds_block) 
    return stack1

# %%
#provide some info
rootdir = '/n/coxfs01/2p-data'


animalid = 'JC084' #'JC120'
session = '20190522' #'20191120'
acquisition = 'FOV1_zoom2p0x' #'FOV1_zoom4p0x'

run_list = [r for r in os.listdir(os.path.join(rootdir, animalid, session, acquisition)) if re.findall(r'_run\d+', r)]
#run_list = ['scenes_run1','scenes_run2','scenes_run3','scenes_run4','scenes_run5','scenes_run6']

run_list
# Out:
# ['blobs_run1',
#  'gratings_run1',
#  'rfs_run1',
#  'blobs_run2',
#  'gratings_run2',
#  'rfs_run2',
#  'blobs_run3',
#  'gratings_run3',
#  'rfs_run3',
#  'blobs_run4',
#  'retino_run1',
#  'gratings_run4',
#  'rfs_run4',
#  'retino_run2',
#  'blobs_run5',
#  'rfs_run5',
#  'blobs_run6',
#  'rfs_run6']

# %%
#figure out directories to search
dst_dir = os.path.join(rootdir, animalid, session, acquisition, 'all_combined', 'block_reduced')
if not os.path.isdir(dst_dir):
    os.makedirs(dst_dir)
for run in run_list:

    data_dir = os.path.join(rootdir,animalid,session,acquisition,run)
    
    raw_dir = glob.glob(os.path.join(data_dir,'raw*'))[0]
    print(raw_dir)
    src_dir = os.path.join(raw_dir,'*.tif')


    for fn in glob.glob(src_dir):

        i0 = findOccurrences(fn,'/')[-1]
        i1 = findOccurrences(fn,'_')[-1]


        new_fn = '%s_%s_%s'%(acquisition,run,fn[i1+1:])
        print(new_fn)


        stack0 = imread(fn)

        stack1 = block_mean_stack(stack0,(2,2))


        print(stack1.shape)

        imsave(os.path.join(dst_dir,new_fn),stack1)
# Out:
# /n/coxfs01/2p-data/JC084/20190522/FOV1_zoom2p0x/blobs_run1/raw_9bd130
# FOV1_zoom2p0x_blobs_run1_00001.tif
# (256, 256)
# (3438, 256, 256)
# FOV1_zoom2p0x_blobs_run1_00002.tif
# (256, 256)
# (3438, 256, 256)
# FOV1_zoom2p0x_blobs_run1_00003.tif
# (256, 256)
# (3438, 256, 256)
# FOV1_zoom2p0x_blobs_run1_00004.tif
# (256, 256)
# (3438, 256, 256)
# FOV1_zoom2p0x_blobs_run1_00005.tif
# (256, 256)
# (3438, 256, 256)
# FOV1_zoom2p0x_blobs_run1_00006.tif
# (256, 256)
# (3438, 256, 256)
# FOV1_zoom2p0x_blobs_run1_00007.tif
# (256, 256)
# (3438, 256, 256)
# FOV1_zoom2p0x_blobs_run1_00008.tif
# (256, 256)
# (3438, 256, 256)
# FOV1_zoom2p0x_blobs_run1_00009.tif
# (256, 256)
# (3438, 256, 256)
# FOV1_zoom2p0x_blobs_run1_00010.tif
# (256, 256)
# (3438, 256, 256)
# /n/coxfs01/2p-data/JC084/20190522/FOV1_zoom2p0x/gratings_run1/raw_d0390b
# FOV1_zoom2p0x_gratings_run1_00001.tif
# (256, 256)
# (4610, 256, 256)
# FOV1_zoom2p0x_gratings_run1_00002.tif
# (256, 256)
# (4610, 256, 256)
# FOV1_zoom2p0x_gratings_run1_00003.tif
# (256, 256)
# (4610, 256, 256)
# FOV1_zoom2p0x_gratings_run1_00004.tif
# (256, 256)
# (4610, 256, 256)
# FOV1_zoom2p0x_gratings_run1_00005.tif
# (256, 256)
# (4610, 256, 256)
# FOV1_zoom2p0x_gratings_run1_00006.tif
# (256, 256)
# (4610, 256, 256)
# FOV1_zoom2p0x_gratings_run1_00007.tif
# (256, 256)
# (4610, 256, 256)
# FOV1_zoom2p0x_gratings_run1_00008.tif
# (256, 256)
# (4610, 256, 256)
# /n/coxfs01/2p-data/JC084/20190522/FOV1_zoom2p0x/rfs_run1/raw_8a27d9
# FOV1_zoom2p0x_rfs_run1_00001.tif
# (256, 256)
# (2911, 256, 256)
# FOV1_zoom2p0x_rfs_run1_00002.tif
# (256, 256)
# (2911, 256, 256)
# FOV1_zoom2p0x_rfs_run1_00003.tif
# (256, 256)
# (2911, 256, 256)
# FOV1_zoom2p0x_rfs_
 256, 256)
# /n/coxfs01/2p-data/JC084/20190522/FOV1_zoom2p0x/gratings_run4/raw_913375
# FOV1_zoom2p0x_gratings_run4_00001.tif
# (256, 256)
# (4610, 256, 256)
# FOV1_zoom2p0x_gratings_run4_00002.tif
# (256, 256)
# (4610, 256, 256)
# FOV1_zoom2p0x_gratings_run4_00003.tif
# (256, 256)
# (4610, 256, 256)
# FOV1_zoom2p0x_gratings_run4_00004.tif
# (256, 256)
# (4610, 256, 256)
# FOV1_zoom2p0x_gratings_run4_00005.tif
# (256, 256)
# (4610, 256, 256)
# FOV1_zoom2p0x_gratings_run4_00006.tif
# (256, 256)
# (4610, 256, 256)
# FOV1_zoom2p0x_gratings_run4_00007.tif
# (256, 256)
# (4610, 256, 256)
# FOV1_zoom2p0x_gratings_run4_00008.tif
# (256, 256)
# (4610, 256, 256)
# /n/coxfs01/2p-data/JC084/20190522/FOV1_zoom2p0x/rfs_run4/raw_7379fb
# FOV1_zoom2p0x_rfs_run4_00001.tif
# (256, 256)
# (2911, 256, 256)
# FOV1_zoom2p0x_rfs_run4_00002.tif
# (256, 256)
# (2911, 256, 256)
# FOV1_zoom2p0x_rfs_run4_00003.tif
# (256, 256)
# (2911, 256, 256)
# FOV1_zoom2p0x_rfs_run4_00004.tif
# (256, 256)
# (2911, 256, 256)
# FOV1_zoom2p0x_rfs_run4_00005.tif
# (256, 256)
# (2911, 256, 256)
# FOV1_zoom2p0x_rfs_run4_00006.tif
# (256, 256)
# (2911, 256, 256)
# FOV1_zoom2p0x_rfs_run4_00007.tif
# (256, 256)
# (2911, 256, 256)
# FOV1_zoom2p0x_rfs_run4_00008.tif
# (256, 256)
# (2911, 256, 256)
# FOV1_zoom2p0x_rfs_run4_00009.tif
# (256, 256)
# (2911, 256, 256)
# FOV1_zoom2p0x_rfs_run4_00010.tif
# (256, 256)
# (2911, 256, 256)
# FOV1_zoom2p0x_rfs_run4_00011.tif
# (256, 256)
# (2911, 256, 256)
# /n/coxfs01/2p-data/JC084/20190522/FOV1_zoom2p0x/retino_run2/raw_6ee6c4
# FOV1_zoom2p0x_retino_run2_00001.tif
# (256, 256)
# (2233, 256, 256)
# FOV1_zoom2p0x_retino_run2_00002.tif
# (256, 256)
# (2233, 256, 256)
# FOV1_zoom2p0x_retino_run2_00003.tif
# (256, 256)
# (2233, 256, 256)
# FOV1_zoom2p0x_retino_run2_00004.tif
# (256, 256)
# (2233, 256, 256)
# FOV1_zoom2p0x_retino_run2_00005.tif
# (256, 256)
# (2233, 256, 256)
# FOV1_zoom2p0x_retino_run2_00006.tif
# (256, 256)
# (2233, 256, 256)
# FOV1_zoom2p0x_retino_run2_00007.tif
# (256, 256)
# (2233, 256, 256)
# FOV1_zoom2p0x_retino_run2_00008.tif
# (256, 256)
# (2233, 256, 256)
# FOV1_zoom2p0x_retino_run2_00009.tif
# (256, 256)
# (2233, 256, 256)
# FOV1_zoom2p0x_retino_run2_00010.tif
# (256, 256)
# (2233, 256, 256)
# FOV1_zoom2p0x_retino_run2_00011.tif
# (256, 256)
# (2233, 256, 256)
# FOV1_zoom2p0x_retino_run2_00012.tif
# (256, 256)
# (2233, 256, 256)
# /n/coxfs01/2p-data/JC084/20190522/FOV1_zoom2p0x/blobs_run5/raw_ab7086
# FOV1_zoom2p0x_blobs_run5_00001.tif
# (256, 256)
# (3438, 256, 256)
# FOV1_zoom2p0x_blobs_run5_00002.tif
# (256, 256)
# (3438, 256, 256)
# FOV1_zoom2p0x_blobs_run5_00003.tif
# (256, 256)
# (3438, 256, 256)
# FOV1_zoom2p0x_blobs_run5_00004.tif
# (256, 256)
# (3438, 256, 256)
# FOV1_zoom2p0x_blobs_run5_00005.tif
# (256, 256)
# (3438, 256, 256)
# FOV1_zoom2p0x_blobs_run5_00006.tif
# (256, 256)
# (3438, 256, 256)
# FOV1_zoom2p0x_blobs_run5_00007.tif
# (256, 256)
# (3438, 256, 256)
# FOV1_zoom2p0x_blobs_run5_00008.tif
# (256, 256)
# (3438, 256, 256)
# FOV1_zoom2p0x_blobs_run5_00009.tif
# (256, 256)
# (3438, 256, 256)
# FOV1_zoom2p0x_blobs_run5_00010.tif
# (256, 256)
# (3438, 256, 256)
# /n/coxfs01/2p-data/JC084/20190522/FOV1_zoom2p0x/rfs_run5/raw_fe613c
# FOV1_zoom2p0x_rfs_run5_00001.tif
# (256, 256)
# (2911, 256, 256)
# FOV1_zoom2p0x_rfs_run5_00002.tif
# (256, 256)
# (2911, 256, 256)
# FOV1_zoom2p0x_rfs_run5_00003.tif
# (256, 256)
# (2911, 256, 256)
# FOV1_zoom2p0x_rfs_run5_00004.tif
# (256, 256)
# (2911, 256, 256)
# FOV1_zoom2p0x_rfs_run5_00005.tif
# (256, 256)
# (2911, 256, 256)
# FOV1_zoom2p0x_rfs_run5_00006.tif
# (256, 256)
# (2911, 256, 256)
# FOV1_zoom2p0x_rfs_run5_00007.tif
# (256, 256)
# (2911, 256, 256)
# FOV1_zoom2p0x_rfs_run5_00008.tif
# (256, 256)
# (2911, 256, 256)
# FOV1_zoom2p0x_rfs_run5_00009.tif
# (256, 256)
# (2911, 256, 256)
# FOV1_zoom2p0x_rfs_run5_00010.tif
# (256, 256)
# (2911, 256, 256)
# FOV1_zoom2p0x_rfs_run5_00011.tif
# (256, 256)
# (2911, 256, 256)
# /n/coxfs01/2p-data/JC084/20190522/FOV1_zoom2p0x/blobs_run6/raw_b42719
# FOV1_zoom2p0x_blobs_run6_00001.tif
# (256, 256)
# (3438, 256, 256)
# FOV1_zoom2p0x_blobs_run6_00002.tif
# (256, 256)
# (3438, 256, 256)
# FOV1_zoom2p0x_blobs_run6_00003.tif
# (256, 256)
# (3438, 256, 256)
# FOV1_zoom2p0x_blobs_run6_00004.tif
# (256, 256)
# (3438, 256, 256)
# FOV1_zoom2p0x_blobs_run6_00005.tif
# (256, 256)
# (3438, 256, 256)
# FOV1_zoom2p0x_blobs_run6_00006.tif
# (256, 256)
# (3438, 256, 256)
# FOV1_zoom2p0x_blobs_run6_00007.tif
# (256, 256)
# (3438, 256, 256)
# FOV1_zoom2p0x_blobs_run6_00008.tif
# (256, 256)
# (3438, 256, 256)
# FOV1_zoom2p0x_blobs_run6_00009.tif
# (256, 256)
# (3438, 256, 256)
# FOV1_zoom2p0x_blobs_run6_00010.tif
# (256, 256)
# (3438, 256, 256)
# /n/coxfs01/2p-data/JC084/20190522/FOV1_zoom2p0x/rfs_run6/raw_dc5043
# FOV1_zoom2p0x_rfs_run6_00001.tif
# (256, 256)
# (2911, 256, 256)
# FOV1_zoom2p0x_rfs_run6_00002.tif
# (256, 256)
# (2911, 256, 256)
# FOV1_zoom2p0x_rfs_run6_00003.tif
# (256, 256)
# (2911, 256, 256)
# FOV1_zoom2p0x_rfs_run6_00004.tif
# (256, 256)
# (2911, 256, 256)
# FOV1_zoom2p0x_rfs_run6_00005.tif
# (256, 256)
# (2911, 256, 256)
# FOV1_zoom2p0x_rfs_run6_00006.tif
# (256, 256)
# (2911, 256, 256)
# FOV1_zoom2p0x_rfs_run6_00007.tif
# (256, 256)
# (2911, 256, 256)
# FOV1_zoom2p0x_rfs_run6_00008.tif
# (256, 256)
# (2911, 256, 256)
# FOV1_zoom2p0x_rfs_run6_00009.tif
# (256, 256)
# (2911, 256, 256)
# FOV1_zoom2p0x_rfs_run6_00010.tif
# (256, 256)
# (2911, 256, 256)
# FOV1_zoom2p0x_rfs_run6_00011.tif
# (256, 256)
# (2911, 256, 256)
