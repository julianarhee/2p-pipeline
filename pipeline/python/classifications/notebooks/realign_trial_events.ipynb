# %%
import os
import glob
import json
from pipeline.python import utils #import get_frame_info
from pipeline.python.paradigm import align_acquisition_events as alignacq

# %%
iti_pre = 1.0
iti_post = 1.0

# %%
rootdir = '/n/coxfs01/2p-data'

session = '20190609'
animalid = 'JC099'
fov = 'FOV1_zoom2p0x'
curr_exp = 'blobs'
traceid = 'traces001'

# %%
fovdir = os.path.join(rootdir, animalid, session, fov)
rundirs = [os.path.split(p)[0] for p in glob.glob(os.path.join(fovdir, '%s_run*' % curr_exp, 'paradigm'))]
rundirs
# Out:
# ['/n/coxfs01/2p-data/JC099/20190609/FOV1_zoom2p0x/blobs_run1',
#  '/n/coxfs01/2p-data/JC099/20190609/FOV1_zoom2p0x/blobs_run2',
#  '/n/coxfs01/2p-data/JC099/20190609/FOV1_zoom2p0x/blobs_run3',
#  '/n/coxfs01/2p-data/JC099/20190609/FOV1_zoom2p0x/blobs_run4',
#  '/n/coxfs01/2p-data/JC099/20190609/FOV1_zoom2p0x/blobs_run5',
#  '/n/coxfs01/2p-data/JC099/20190609/FOV1_zoom2p0x/blobs_run6']

# %%
for rundir in rundirs:

    si_info = utils.get_frame_info(rundir) 
    paradigm_dir = os.path.join(rundir, 'paradigm')  
    trial_info = alignacq.get_alignment_specs(paradigm_dir, si_info, iti_pre=iti_pre, iti_post=iti_post)
    
    # Save alignment info
    traceid_dir = glob.glob(os.path.join(rundir, 'traces', '%s*' % traceid))
    assert len(traceid_dir)==1, "More than 1 tracedid path found..."
    traceid_dir = traceid_dir[0]
    alignment_info_filepath = os.path.join(traceid_dir, 'event_alignment.json')
    with open(alignment_info_filepath, 'w') as f:
        json.dump(trial_info, f, sort_keys=True, indent=4)       

    # Get parsed frame indices
    parsed_frames_filepath = alignacq.assign_frames_to_trials(si_info, trial_info, paradigm_dir, create_new=True)
# Out:
# Found ITI durs: [2.0]
# Unique itis (minus jitter from max): [2.0]
# ITI POST: 1.0
# ---> Creating NEW parsed-frames file...
# ... File001, 25
# ... File002, 25
# ... File003, 25
# ... File004, 25
# ... File005, 25
# ... File006, 25
# ... File007, 25
# ... File008, 25
# ... File009, 25
# ... File010, 25
# Hashed file: /n/coxfs01/2p-data/JC099/20190609/FOV1_zoom2p0x/blobs_run1/paradigm/parsed_frames_3991f2.hdf5
# Set READ-ONLY.
# Finished assigning frame idxs across all tiffs to trials in run blobs_run1.
# Saved parsed frame info to file: /n/coxfs01/2p-data/JC099/20190609/FOV1_zoom2p0x/blobs_run1/paradigm/parsed_frames_3991f2.hdf5
# -----------------------------------------------------------------------
# Found ITI durs: [2.0]
# Unique itis (minus jitter from max): [2.0]
# ITI POST: 1.0
# ---> Creating NEW parsed-frames file...
# ... File001, 25
# ... File002, 25
# ... File003, 25
# ... File004, 25
# ... File005, 25
# ... File006, 25
# ... File007, 25
# ... File008, 25
# ... File009, 25
# ... File010, 25
# Hashed file: /n/coxfs01/2p-data/JC099/20190609/FOV1_zoom2p0x/blobs_run2/paradigm/parsed_frames_5740fd.hdf5
# Set READ-ONLY.
# Finished assigning frame idxs across all tiffs to trials in run blobs_run2.
# Saved parsed frame info to file: /n/coxfs01/2p-data/JC099/20190609/FOV1_zoom2p0x/blobs_run2/paradigm/parsed_frames_5740fd.hdf5
# -----------------------------------------------------------------------
# Found ITI durs: [2.0]
# Unique itis (minus jitter from max): [2.0]
# ITI POST: 1.0
# ---> Creating NEW parsed-frames file...
# ... File001, 25
# ... File002, 25
# ... File003, 25
# ... File004, 25
# ... File005, 25
# ... File006, 25
# ... File007, 25
# ... File008, 25
# ... File009, 25
# ... File010, 25
# Hashed file: /n/coxfs01/2p-data/JC099/20190609/FOV1_zoom2p0x/blobs_run3/paradigm/parsed_frames_5284ec.hdf5
# Set READ-ONLY.
# Finished assigning frame idxs across all tiffs to trials in run blobs_run3.
# Saved parsed frame info to file: /n/coxfs01/2p-data/JC099/20190609/FOV1_zoom2p0x/blobs_run3/paradigm/parsed_frames_5284ec.hdf5
# -----------------------------------------------------------------------
# Found ITI durs: [2.0]
# Unique itis (minus jitter from max): [2.0]
# ITI POST: 1.0
# ---> Creating NEW parsed-frames file...
# ... File001, 25
# ... File002, 25
# ... File003, 25
# ... File004, 25
# ... File005, 25
# ... File006, 25
# ... File007, 25
# ... File008, 25
# ... File009, 25
# ... File010, 25
# Hashed file: /n/coxfs01/2p-data/JC099/20190609/FOV1_zoom2p0x/blobs_run4/paradigm/parsed_frames_92ef27.hdf5
# Set READ-ONLY.
# Finished assigning frame idxs across all tiffs to trials in run blobs_run4.
# Saved parsed frame info to file: /n/coxfs01/2p-data/JC099/20190609/FOV1_zoom2p0x/blobs_run4/paradigm/parsed_frames_92ef27.hdf5
# -----------------------------------------------------------------------
# Found ITI durs: [2.0]
# Unique itis (minus jitter from max): [2.0]
# ITI POST: 1.0
# ---> Creating NEW parsed-frames file...
# ... File001, 25
# ... File002, 25
# ... File003, 25
# ... File004, 25
# ... File005, 25
# ... File006, 25
# ... File007, 25
# ... File008, 25
# ... File009, 25
# ... File010, 25
# Hashed file: /n/coxfs01/2p-data/JC099/20190609/FOV1_zoom2p0x/blobs_run5/paradigm/parsed_frames_df9c27.hdf5
# Set READ-ONLY.
# Finished assigning frame idxs across all tiffs to trials in run blobs_run5.
# Saved parsed frame info to file: /n/coxfs01/2p-data/JC099/20190609/FOV1_zoom2p0x/blobs_run5/paradigm/parsed_frames_df9c27.hdf5
# -----------------------------------------------------------------------
# Found ITI durs: [2.0]
# Unique itis (minus jitter from max): [2.0]
# ITI POST: 1.0
# ---> Creating NEW parsed-frames file...
# ... File001, 25
# ... File002, 25
# ... File003, 25
# ... File004, 25
# ... File005, 25
# ... File006, 25
# ... File007, 25
# ... File008, 25
# ... File009, 25
# ... File010, 25
# Hashed file: /n/coxfs01/2p-data/JC099/20190609/FOV1_zoom2p0x/blobs_run6/paradigm/parsed_frames_4985d0.hdf5
# Set READ-ONLY.
# Finished assigning frame idxs across all tiffs to trials in run blobs_run6.
# Saved parsed frame info to file: /n/coxfs01/2p-data/JC099/20190609/FOV1_zoom2p0x/blobs_run6/paradigm/parsed_frames_4985d0.hdf5
# -----------------------------------------------------------------------

# %%
# Realign traces

# %%
from pipeline.python.classifications import experiment_classes as cutils

# %%
response_type = 'dff'

# %%
# Load experiment neural data
exp = cutils.Objects(animalid, session, fov, traceid=traceid)
exp.load(trace_type=response_type, update_self=True, make_equal=False, create_new=True)
# Out:
# ... [JC099|20190609|FOV1_zoom2p0x] creating blobs object
# GET ROI SET: rois001
# ... getting data paths - name: blobs
# ... renaming experiment to run name: combined_blobs_static
# ... loading data array
# /n/coxfs01/2p-data/JC099/20190609/FOV1_zoom2p0x/combined_blobs_static/traces/traces001_2be711_traces001_333f6c_traces001_31bd42_traces001_0b8503_traces001_2d8e76_traces001_8fe19c/data_arrays/np_subtracted.npz
# *****corrected offset unfound, running now*****
# JC099 | 20190609 | FOV1_zoom2p0x | blobs | traces001
# Found 60 raw file arrays.
# **** File 1 of 60 *****
# *** Excluding: []
# /n/coxfs01/2p-data/JC099/20190609/FOV1_zoom2p0x/blobs_run1
# N tsecs: 3438
# There are 250 total trials across all .tif files.
# Frame indices are NOT block indexed
# ... N frames to align: 3375
# ... N unique frames: 3375
# ... File: 0 (has 3438 frames)
# ... asking for 14 extra frames...
# ... Last frame to align: 3452 (N frames total, 3438)
# ... N tstamps: 3438
# ... padding trial tstamps array... (should be 3375)
# N frames per trial: 135
# N tstamps: 3375
# N trials in block: 25
# ('Excluding:', [u'filehash', u'filepath'])
# ... processing trace type: neuropil
# ('drift offset:', 385.59747787686632)
# Showing initial drift correction (quantile: 0.10)
# Min value for all ROIs: -97.3727490996
# ... processing trace type: np_subtracted
# ('drift offset:', -16.872976232723015)
# Showing initial drift correction (quantile: 0.10)
# Min value for all ROIs: -280.4501718
# ... processing trace type: raw
# ('drift offset:', 277.36481407034836)
# Showing initial drift correction (quantile: 0.10)
# Min value for all ROIs: -313.963321461
# STIM TYPE: image
# **** File 2 of 60 *****
# *** Excluding: []
# /n/coxfs01/2p-data/JC099/20190609/FOV1_zoom2p0x/blobs_run1
# N tsecs: 3438
# There are 250 total trials across all .tif files.
# Frame indices are NOT block indexed
# ... N frames to align: 3375
# ... N unique frames: 3375
# ... File: 1 (has 3438 frames)
# ... asking for 13 extra frames...
# ... Last frame to align: 3451 (N frames total, 3438)
# ... N tstamps: 3438
# ... padding trial tstamps array... (should be 3375)
# N frames per trial: 135
# N tstamps: 3375
# N trials in block: 25
# ('Excluding:', [u'filehash', u'filepath'])
# ... processing trace type: neuropil
# ('drift offset:', 385.40170375574189)
# Showing initial drift correction (quantile: 0.10)
# Min value for all ROIs: -97.7375776398
# ... processing trace type: np_subtracted
# ('drift offset:', -15.843475327090127)
# Showing initial drift correction (quantile: 0.10)
# Min value for all ROIs: -274.942137044
# ... processing trace type: raw
# ('drift offset:', 275.84378819522487)
# Showing initial drift correction (quantile: 0.10)
# Min value for all ROIs: -265.947027439
# STIM TYPE: image
# **** File 3 of 60 *****
# *** Excluding: []
# /n/coxfs01/2p-data/JC099/20190609/FOV1_zoom2p0x/blobs_run1
# N tsecs: 3438
# There are 250 total trials across all .tif files.
# Frame indices are NOT block indexed
# ... N frames to align: 3375
# ... N unique frames: 3375
# ... File: 2 (has 3438 frames)
# ... asking for 14 extra frames...
# ... Last frame to align: 3452 (N frames total, 3438)
# ... N tstamps: 3438
# ... padding trial tstamps array... (should be 3375)
# N frames per trial: 135
# N tstamps: 3375
# N trials in block: 25
# ('Excluding:', [u'filehash', u'filepath'])
# ... processing trace type: neuropil
# ('drift offset:', 379.2663740355909)
# Showing initial drift correction (quantile: 0.10)
# Min value for all ROIs: -109.128283445
# ... processing trace type: np_subtracted
# ('drift offset:', -18.315528641386713)
# Showing initial drift correction (quantile: 0.10)
# Min value for all ROIs: -366.169112769
# ... processing trace type: raw
# ('drift offset:', 268.76269884521264)
# Showing initial drift correction (quantile: 0.10)
# Min value for all ROIs: -362.701388889
# STIM TYPE: image
# **** File 4 of 60 *****
# *** Excluding: []
# /n/coxfs01/2p-data/JC099/20190609/FOV1_zoom2p0x/blobs_run1
# N tsecs: 3438
# There are 250 total trials across all .tif files.
# Frame indices are NOT block indexed
# ... N frames to align: 3375
# ... N unique frames: 3375
# ... File: 3 (has 3438 frames)
# ... asking for 14 extra frames...
# ... Last frame to align: 3452 (N frames total, 3438)
# ... N tstamps: 3438
# ... padding trial tstamps array... (should be 3375)
# N frames per trial: 135
# N tstamps: 3375
# N trials in block: 25
# ('Excluding:', [u'filehash', u'filepath'])
# ... processing trace type: neuropil
# ('drift offset:', 384.25111136764093)
# Showing initial drift correction (quantile: 0.10)
# Min value for all ROIs: -118.040114613
# ... processing trace type: np_subtracted
# ('drift offset:', -23.24975533630867)
# Showing initial drift correction (quantile: 0.10)
# Min value for all ROIs: -307.520916052
# ... processing trace type: raw
# ('drift offset:', 266.45704315340356)
# Showing initial drift correction (quantile: 0.10)
# Min value for all ROIs: -279.569163603
# STIM TYPE: image
# **** File 5 of 60 *****
# *** Excluding: []
# /n/coxfs01/2p-data/JC099/20190609/FOV1_zoom2p0x/blobs_run1
# N tsecs: 3438
# There are 250 total trials across all .tif files.
# Frame indices are NOT block indexed
# ... N frames to align: 3375
# ... N unique frames: 3375
# ... File: 4 (has 3438 frames)
# ... asking for 13 extra frames...
# ... Last frame to align: 3451 (N frames total, 3438)
# ... N tstamps: 3438
# ... padding trial tstamps array... (should be 3375)
# N frames per trial: 135
# N tstamps: 3375
# N trials in block: 25
# ('Excluding:', [u'filehash', u'filepath'])
# ... processing trace type: neuropil
# ('drift offset:', 381.33168169709938)
# Showing initial drift correction (quantile: 0.10)
# Min value for all ROIs: -152.487995198
# ... processing trace type: np_subtracted
# ('drift offset:', -21.716639202833033)
# Showing initial drift correction (quantile: 0.10)
# Min value for all ROIs: -295.010031264
# ... processing trace type: raw
# ('drift offset:', 267.00194211625791)
# Showing initial drift correction (quantile: 0.10)
# Min value for all ROIs: -310.19034352
# STIM TYPE: image
# **** File 6 of 60 *****
# *** Excluding: []
# /n/coxfs01/2p-data/JC099/20190609/FOV1_zoom2p0x/blobs_run1
# N tsecs: 3438
# There are 250 total trials across all .tif files.
# Frame indices are NOT block indexed
# ... N frames to align: 3375
# ... N unique frames: 3375
# ... File: 5 (has 3438 frames)
# ... asking for 13 extra frames...
# ... Last frame to align: 3451 (N frames total, 3438)
# ... N tstamps: 3438
# ... padding trial tstamps array... (should be 3375)
# N frames per trial: 135
# N tstamps: 3375
# N trials in block: 25
# ('Excluding:', [u'filehash', u'filepath'])
# ... processing trace type: neuropil
# ('drift offset:', 387.36514369313841)
# Showing initial drift correction (quantile: 0.10)
# Min value for all ROIs: -99.9953416149
# ... processing trace type: np_subtracted
# ('drift offset:', -21.163072073664239)
# Showing initial drift correction (quantile: 0.10)
# Min value for all ROIs: -327.05116747
# ... processing trace type: raw
# ('drift offset:', 271.96962132841111)
# Showing initial drift correction (quantile: 0.10)
# Min value for all ROIs: -355.020833333
# STIM TYPE: image
# **** File 7 of 60 *****
# *** Excluding: []
# /n/coxfs01/2p-data/JC099/20190609/FOV1_zoom2p0x/blobs_run1
# N tsecs: 3438
# There are 250 total trials across all .tif files.
# Frame indices are NOT block indexed
# ... N frames to align: 3375
# ... N unique frames: 3375
# ... File: 6 (has 3438 frames)
# ... asking for 13 extra frames...
# ... Last frame to align: 3451 (N frames total, 3438)
# ... N tstamps: 3438
# ... padding trial tstamps array... (should be 3375)
# N frames per trial: 135
# N tstamps: 3375
# N trials in block: 25
# ('Excluding:', [u'filehash', u'filepath'])
# ... processing trace type: neuropil
# ('drift offset:', 389.42340141361308)
# Showing initial drift correction (quantile: 0.10)
# Min value for all ROIs: -96.0916310324
# ... processing trace type: np_subtracted
# ('drift offset:', -20.0214991406034)
# Showing initial drift correction (quantile: 0.10)
# Min value for all ROIs: -327.761297138
# ... processing trace type: raw
# ('drift offset:', 273.54186337409789)
# Showing initial drift correction (quantile: 0.10)
# Min value for all ROIs: -344.62109375
# STIM TYPE: image
# **** File 8 of 60 *****
# *** Excluding: []
# /n/coxfs01/2p-data/JC099/20190609/FOV1_zoom2p0x/blobs_run1
# N tsecs: 3438
# There are 250 total trials across all .tif files.
# Frame indices are NOT block indexed
# ... N frames to align: 3375
# ... N unique frames: 3375
# ... File: 7 (has 3438 frames)
# ... asking for 14 extra frames...
# ... Last frame to align: 3452 (N frames total, 3438)
# ... N tstamps: 3438
# ... padding trial tstamps array... (should be 3375)
# N frames per trial: 135
# N tstamps: 3375
# N trials in block: 25
# ('Excluding:', [u'filehash', u'filepath'])
# ... processing trace type: neuropil
# ('drift offset:', 385.02597666806344)
# Showing initial drift correction (quantile: 0.10)
# Min value for all ROIs: -100.846059866
# ... processing trace type: np_subtracted
# ('drift offset:', -18.52820093037268)
# Showing initial drift correction (quantile: 0.10)
# Min value for all ROIs: -251.696057415
# ... processing trace type: raw
# ('drift offset:', 272.02381864295444)
# Showing initial drift correction (quantile: 0.10)
# Min value for all ROIs: -280.545445884
# STIM TYPE: image
# **** File 9 of 60 *****
# *** Excluding: []
# /n/coxfs01/2p-data/JC099/20190609/FOV1_zoom2p0x/blobs_run1
# N tsecs: 3438
# There are 250 total trials across all .tif files.
# Frame indices are NOT block indexed
# ... N frames to align: 3375
# ... N unique frames: 3375
# ... File: 8 (has 3438 frames)
# ... asking for 14 extra frames...
# ... Last frame to align: 3452 (N frames total, 3438)
# ... N tstamps: 3438
# ... padding trial tstamps array... (should be 3375)
# N frames per trial: 135
# N tstamps: 3375
# N trials in block: 25
# ('Excluding:', [u'filehash', u'filepath'])
# ... processing trace type: neuropil
# ('drift offset:', 388.07201129484389)
# Showing initial drift correction (quantile: 0.10)
# Min value for all ROIs: -111.763975155
# ... processing trace type: np_subtracted
# ('drift offset:', -15.339765003101336)
# Showing initial drift correction (quantile: 0.10)
# Min value for all ROIs: -329.412294121
# ... processing trace type: raw
# ('drift offset:', 278.56828190658615)
# Showing initial drift correction (quantile: 0.10)
# Min value for all ROIs: -324.066834985
# STIM TYPE: image
# **** File 10 of 60 *****
# *** Excluding: []
# /n/coxfs01/2p-data/JC099/20190609/FOV1_zoom2p0x/blobs_run1
# N tsecs: 3438
# There are 250 total trials across all .tif files.
# Frame indices are NOT block indexed
# ... N frames to align: 3375
# ... N unique frames: 3375
# ... File: 9 (has 3438 frames)
# ... asking for 14 extra frames...
# ... Last frame to align: 3452 (N frames total, 3438)
# ... N tstamps: 3438
# ... padding trial tstamps array... (should be 3375)
# N frames per trial: 135
# N tstamps: 3375
# N trials in block: 25
# ('Excluding:', [u'filehash', u'filepath'])
# ... processing trace type: neuropil
# ('drift offset:', 385.03306004302141)
# Showing initial drift correction (quantile: 0.10)
# Min value for all ROIs: -117.597238896
# ... processing trace type: np_subtracted
# ('drift offset:', -16.610132474416474)
# Showing initial drift correction (quantile: 0.10)
# Min value for all ROIs: -272.145194812
# ... processing trace type: raw
# ('drift offset:', 274.42782853235207)
# Showing initial drift correction (quantile: 0.10)
# Min value for all ROIs: -306.979849466
# STIM TYPE: image
# **** File 11 of 60 *****
# *** Excluding: []
# /n/coxfs01/2p-data/JC099/20190609/FOV1_zoom2p0x/blobs_run2
# N tsecs: 3438
# There are 250 total trials across all .tif files.
# Frame indices are NOT block indexed
# ... N frames to align: 3375
# ... N unique frames: 3375
# ... File: 0 (has 3438 frames)
# ... asking for 13 extra frames...
# ... Last frame to align: 3451 (N frames total, 3438)
# ... N tstamps: 3438
# ... padding trial tstamps array... (should be 3375)
# N frames per trial: 135
# N tstamps: 3375
# N trials in block: 25
# ('Excluding:', [u'filehash', u'filepath'])
# ... processing trace type: neuropil
# ('drift offset:', 370.11762039754529)
# Showing initial drift correction (quantile: 0.10)
# Min value for all ROIs: -94.9323503903
# ... processing trace type: np_subtracted
# ('drift offset:', -18.94192321098334)
# Showing initial drift correction (quantile: 0.10)
# Min value for all ROIs: -220.182975006
# ... processing trace type: raw
# ('drift offset:', 261.54415019444065)
# Showing initial drift correction (quantile: 0.10)
# Min value for all ROIs: -293.906172903
# STIM TYPE: image
# **** File 12 of 60 *****
# *** Excluding: []
# /n/coxfs01/2p-data/JC099/20190609/FOV1_zoom2p0x/blobs_run2
# N tsecs: 3438
# There are 250 total trials across all .tif files.
# Frame indices are NOT block indexed
# ... N frames to align: 3375
# ... N unique frames: 3375
# ... File: 1 (has 3438 frames)
# ... asking for 13 extra frames...
# ... Last frame to align: 3451 (N frames total, 3438)
# ... N tstamps: 3438
# ... padding trial tstamps array... (should be 3375)
# N frames per trial: 135
# N tstamps: 3375
# N trials in block: 25
# ('Excluding:', [u'filehash', u'filepath'])
# ... processing trace type: neuropil
# ('drift offset:', 370.63876758357196)
# Showing initial drift correction (quantile: 0.10)
# Min value for all ROIs: -655.888317414
# ... processing trace type: np_subtracted
# ('drift offset:', -19.513380026856311)
# Showing initial drift correction (quantile: 0.10)
# Min value for all ROIs: -439.009685917
# ... processing trace type: raw
# ('drift offset:', 261.93778947156733)
# Showing initial drift correction (quantile: 0.10)
# Min value for all ROIs: -710.082380022
# STIM TYPE: image
# **** File 13 of 60 *****
# *** Excluding: []
# /n/coxfs01/2p-data/JC099/20190609/FOV1_zoom2p0x/blobs_run2
# N tsecs: 3438
# There are 250 total trials across all .tif files.
# Frame indices are NOT block indexed
# ... N frames to align: 3375
# ... N unique frames: 3375
# ... File: 2 (has 3438 frames)
# ... asking for 13 extra frames...
# ... Last frame to align: 3451 (N frames total, 3438)
# ... N tstamps: 3438
# ... padding trial tstamps array... (should be 3375)
# N frames per trial: 135
# N tstamps: 3375
# N trials in block: 25
# ('Excluding:', [u'filehash', u'filepath'])
# ... processing trace type: neuropil
# ('drift offset:', 359.01483734476437)
# Showing initial drift correction (quantile: 0.10)
# Min value for all ROIs: -74.8026315789
# ... processing trace type: np_subtracted
# ('drift offset:', -19.880606981300676)
# Showing initial drift correction (quantile: 0.10)
# Min value for all ROIs: -258.909232092
# ... processing trace type: raw
# ('drift offset:', 250.33774117358431)
# Showing initial drift correction (quantile: 0.10)
# Min value for all ROIs: -249.22298971
# STIM TYPE: image
# **** File 14 of 60 *****
# *** Excluding: []
# /n/coxfs01/2p-data/JC099/20190609/FOV1_zoom2p0x/blobs_run2
# N tsecs: 3438
# There are 250 total trials across all .tif files.
# Frame indices are NOT block indexed
# ... N frames to align: 3375
# ... N unique frames: 3375
# ... File: 3 (has 3438 frames)
# ... asking for 13 extra frames...
# ... Last frame to align: 3451 (N frames total, 3438)
# ... N tstamps: 3438
# ... padding trial tstamps array... (should be 3375)
# N frames per trial: 135
# N tstamps: 3375
# N trials in block: 25
# ('Excluding:', [u'filehash', u'filepath'])
# ... processing trace type: neuropil
# ('drift offset:', 354.32237421857457)
# Showing initial drift correction (quantile: 0.10)
# Min value for all ROIs: -88.4272809395
# ... processing trace type: np_subtracted
# ('drift offset:', -19.302338533701487)
# Showing initial drift correction (quantile: 0.10)
# Min value for all ROIs: -248.001107363
# ... processing trace type: raw
# ('drift offset:', 249.47632035536006)
# Showing initial drift correction (quantile: 0.10)
# Min value for all ROIs: -246.481494141
# STIM TYPE: image
# **** File 15 of 60 *****
# *** Excluding: []
# /n/coxfs01/2p-data/JC099/20190609/FOV1_zoom2p0x/blobs_run2
# N tsecs: 3438
# There are 250 total trials across all .tif files.
# Frame indices are NOT block indexed
# ... N frames to align: 3375
# ... N unique frames: 3375
# ... File: 4 (has 3438 frames)
# ... asking for 13 extra frames...
# ... Last frame to align: 3451 (N frames total, 3438)
# ... N tstamps: 3438
# ... padding trial tstamps array... (should be 3375)
# N frames per trial: 135
# N tstamps: 3375
# N trials in block: 25
# ('Excluding:', [u'filehash', u'filepath'])
# ... processing trace type: neuropil
# ('drift offset:', 340.23247666043443)
# Showing initial drift correction (quantile: 0.10)
# Min value for all ROIs: -100.054176072
# ... processing trace type: np_subtracted
# ('drift offset:', -19.295178376571158)
# Showing initial drift correction (quantile: 0.10)
# Min value for all ROIs: -280.873933391
# ... processing trace type: raw
# ('drift offset:', 238.36784299432293)
# Showing initial drift correction (quantile: 0.10)
# Min value for all ROIs: -295.131716845
# STIM TYPE: image
# **** File 16 of 60 *****
# *** Excluding: []
# /n/coxfs01/2p-data/JC099/20190609/FOV1_zoom2p0x/blobs_run2
# N tsecs: 3438
# There are 250 total trials across all .tif files.
# Frame indices are NOT block indexed
# ... N frames to align: 3375
# ... N unique frames: 3375
# ... File: 5 (has 3438 frames)
# ... asking for 13 extra frames...
# ... Last frame to align: 3451 (N frames total, 3438)
# ... N tstamps: 3438
# ... padding trial tstamps array... (should be 3375)
# N frames per trial: 135
# N tstamps: 3375
# N trials in block: 25
# ('Excluding:', [u'filehash', u'filepath'])
# ... processing trace type: neuropil
# ('drift offset:', 350.00108020031314)
# Showing initial drift correction (quantile: 0.10)
# Min value for all ROIs: -84.8136835675
# ... processing trace type: np_subtracted
# ('drift offset:', -17.40392009274936)
# Showing initial drift correction (quantile: 0.10)
# Min value for all ROIs: -263.907922883
# ... processing trace type: raw
# ('drift offset:', 246.67377338108273)
# Showing initial drift correction (quantile: 0.10)
# Min value for all ROIs: -284.056315104
# STIM TYPE: image
# **** File 17 of 60 *****
# *** Excluding: []
# /n/coxfs01/2p-data/JC099/20190609/FOV1_zoom2p0x/blobs_run2
# N tsecs: 3438
# There are 250 total trials across all .tif files.
# Frame indices are NOT block indexed
# ... N frames to align: 3375
# ... N unique frames: 3375
# ... File: 6 (has 3438 frames)
# ... asking for 13 extra frames...
# ... Last frame to align: 3451 (N frames total, 3438)
# ... N tstamps: 3438
# ... padding trial tstamps array... (should be 3375)
# N frames per trial: 135
# N tstamps: 3375
# N trials in block: 25
# ('Excluding:', [u'filehash', u'filepath'])
# ... processing trace type: neuropil
# ('drift offset:', 344.01322561703711)
# Showing initial drift correction (quantile: 0.10)
# Min value for all ROIs: -138.753488372
# ... processing trace type: np_subtracted
# ('drift offset:', -16.310419509857283)
# Showing initial drift correction (quantile: 0.10)
# Min value for all ROIs: -281.942590928
# ... processing trace type: raw
# ('drift offset:', 243.64300538353078)
# Showing initial drift correction (quantile: 0.10)
# Min value for all ROIs: -290.987185595
# STIM TYPE: image
# **** File 18 of 60 *****
# *** Excluding: []
# /n/coxfs01/2p-data/JC099/20190609/FOV1_zoom2p0x/blobs_run2
# N tsecs: 3438
# There are 250 total trials across all .tif files.
# Frame indices are NOT block indexed
# ... N frames to align: 3375
# ... N unique frames: 3375
# ... File: 7 (has 3438 frames)
# ... asking for 13 extra frames...
# ... Last frame to align: 3451 (N frames total, 3438)
# ... N tstamps: 3438
# ... padding trial tstamps array... (should be 3375)
# N frames per trial: 135
# N tstamps: 3375
# N trials in block: 25
# ('Excluding:', [u'filehash', u'filepath'])
# ... processing trace type: neuropil
# ('drift offset:', 349.56037364915545)
# Showing initial drift correction (quantile: 0.10)
# Min value for all ROIs: -80.9458239278
# ... processing trace type: np_subtracted
# ('drift offset:', -15.491183220450887)
# Showing initial drift correction (quantile: 0.10)
# Min value for all ROIs: -255.516332107
# ... processing trace type: raw
# ('drift offset:', 251.15250215382051)
# Showing initial drift correction (quantile: 0.10)
# Min value for all ROIs: -260.164753239
# STIM TYPE: image
# **** File 19 of 60 *****
# *** Excluding: []
# /n/coxfs01/2p-data/JC099/20190609/FOV1_zoom2p0x/blobs_run2
# N tsecs: 3438
# There are 250 total trials across all .tif files.
# Frame indices are NOT block indexed
# ... N frames to align: 3375
# ... N unique frames: 3375
# ... File: 8 (has 3438 frames)
# ... asking for 13 extra frames...
# ... Last frame to align: 3451 (N frames total, 3438)
# ... N tstamps: 3438
# ... padding trial tstamps array... (should be 3375)
# N frames per trial: 135
# N tstamps: 3375
# N trials in block: 25
# ('Excluding:', [u'filehash', u'filepath'])
# ... processing trace type: neuropil
# ('drift offset:', 357.59517919282132)
# Showing initial drift correction (quantile: 0.10)
# Min value for all ROIs: -96.4288299156
# ... processing trace type: np_subtracted
# ('drift offset:', -16.049531058585043)
# Showing initial drift correction (quantile: 0.10)
# Min value for all ROIs: -272.520789017
# ... processing trace type: raw
# ('drift offset:', 252.62103160650756)
# Showing initial drift correction (quantile: 0.10)
# Min value for all ROIs: -254.905725991
# STIM TYPE: image
# **** File 20 of 60 *****
# *** Excluding: []
# /n/coxfs01/2p-data/JC099/20190609/FOV1_zoom2p0x/blobs_run2
# N tsecs: 3438
# There are 250 total trials across all .tif files.
# Frame indices are NOT block indexed
# ... N frames to align: 3375
# ... N unique frames: 3375
# ... File: 9 (has 3438 frames)
# ... asking for 13 extra frames...
# ... Last frame to align: 3451 (N frames total, 3438)
# ... N tstamps: 3438
# ... padding trial tstamps array... (should be 3375)
# N frames per trial: 135
# N tstamps: 3375
# N trials in block: 25
# ('Excluding:', [u'filehash', u'filepath'])
# ... processing trace type: neuropil
# ('drift offset:', 356.24810027312236)
# Showing initial drift correction (quantile: 0.10)
# Min value for all ROIs: -83.9459665145
# ... processing trace type: np_subtracted
# ('drift offset:', -17.543984527825884)
# Showing initial drift correction (quantile: 0.10)
# Min value for all ROIs: -281.174339827
# ... processing trace type: raw
# ('drift offset:', 249.6557399349922)
# Showing initial drift correction (quantile: 0.10)
# Min value for all ROIs: -307.288934005
# STIM TYPE: image
# **** File 21 of 60 *****
# *** Excluding: []
# /n/coxfs01/2p-data/JC099/20190609/FOV1_zoom2p0x/blobs_run3
# N tsecs: 3438
# There are 250 total trials across all .tif files.
# Frame indices are NOT block indexed
# ... N frames to align: 3375
# ... N unique frames: 3375
# ... File: 0 (has 3438 frames)
# ... asking for 13 extra frames...
# ... Last frame to align: 3451 (N frames total, 3438)
# ... N tstamps: 3438
# ... padding trial tstamps array... (should be 3375)
# N frames per trial: 135
# N tstamps: 3375
# N trials in block: 25
# ('Excluding:', [u'filehash', u'filepath'])
# ... processing trace type: neuropil
# ('drift offset:', 408.26170583563038)
# Showing initial drift correction (quantile: 0.10)
# Min value for all ROIs: -97.606805293
# ... processing trace type: np_subtracted
# ('drift offset:', -9.2973504339631603)
# Showing initial drift correction (quantile: 0.10)
# Min value for all ROIs: -257.424519493
# ... processing trace type: raw
# ('drift offset:', 300.58926399466156)
# Showing initial drift correction (quantile: 0.10)
# Min value for all ROIs: -310.017244665
# STIM TYPE: image
# **** File 22 of 60 *****
# *** Excluding: []
# /n/coxfs01/2p-data/JC099/20190609/FOV1_zoom2p0x/blobs_run3
# N tsecs: 3438
# There are 250 total trials across all .tif files.
# Frame indices are NOT block indexed
# ... N frames to align: 3375
# ... N unique frames: 3375
# ... File: 1 (has 3438 frames)
# ... asking for 13 extra frames...
# ... Last frame to align: 3451 (N frames total, 3438)
# ... N tstamps: 3438
# ... padding trial tstamps array... (should be 3375)
# N frames per trial: 135
# N tstamps: 3375
# N trials in block: 25
# ('Excluding:', [u'filehash', u'filepath'])
# ... processing trace type: neuropil
# ('drift offset:', 411.62079980130426)
# Showing initial drift correction (quantile: 0.10)
# Min value for all ROIs: -90.2229688454
# ... processing trace type: np_subtracted
# ('drift offset:', 0.90756782947934533)
# Showing initial drift correction (quantile: 0.10)
# Min value for all ROIs: -306.816663204
# ... processing trace type: raw
# ('drift offset:', 310.93423567846548)
# Showing initial drift correction (quantile: 0.10)
# Min value for all ROIs: -326.488151042
# STIM TYPE: image
# **** File 23 of 60 *****
# *** Excluding: []
# /n/coxfs01/2p-data/JC099/20190609/FOV1_zoom2p0x/blobs_run3
# N tsecs: 3438
# There are 250 total trials across all .tif files.
# Frame indices are NOT block indexed
# ... N frames to align: 3375
# ... N unique frames: 3375
# ... File: 2 (has 3438 frames)
# ... asking for 13 extra frames...
# ... Last frame to align: 3451 (N frames total, 3438)
# ... N tstamps: 3438
# ... padding trial tstamps array... (should be 3375)
# N frames per trial: 135
# N tstamps: 3375
# N trials in block: 25
# ('Excluding:', [u'filehash', u'filepath'])
# ... processing trace type: neuropil
# ('drift offset:', 413.50943892342633)
# Showing initial drift correction (quantile: 0.10)
# Min value for all ROIs: -109.38721351
# ... processing trace type: np_subtracted
# ('drift offset:', 6.0326818337374428)
# Showing initial drift correction (quantile: 0.10)
# Min value for all ROIs: -308.08658391
# ... processing trace type: raw
# ('drift offset:', 319.58631439247733)
# Showing initial drift correction (quantile: 0.10)
# Min value for all ROIs: -379.383522727
# STIM TYPE: image
# **** File 24 of 60 *****
# *** Excluding: []
# /n/coxfs01/2p-data/JC099/20190609/FOV1_zoom2p0x/blobs_run3
# N tsecs: 3438
# There are 250 total trials across all .tif files.
# Frame indices are NOT block indexed
# ... N frames to align: 3375
# ... N unique frames: 3375
# ... File: 3 (has 3438 frames)
# ... asking for 13 extra frames...
# ... Last frame to align: 3451 (N frames total, 3438)
# ... N tstamps: 3438
# ... padding trial tstamps array... (should be 3375)
# N frames per trial: 135
# N tstamps: 3375
# N trials in block: 25
# ('Excluding:', [u'filehash', u'filepath'])
# ... processing trace type: neuropil
# ('drift offset:', 393.78691846083188)
# Showing initial drift correction (quantile: 0.10)
# Min value for all ROIs: -112.325196164
# ... processing trace type: np_subtracted
# ('drift offset:', -13.99827786929445)
# Showing initial drift correction (quantile: 0.10)
# Min value for all ROIs: -291.18801813
# ... processing trace type: raw
# ('drift offset:', 283.89760568215638)
# Showing initial drift correction (quantile: 0.10)
# Min value for all ROIs: -237.972241211
# STIM TYPE: image
# **** File 25 of 60 *****
# *** Excluding: []
# /n/coxfs01/2p-data/JC099/20190609/FOV1_zoom2p0x/blobs_run3
# N tsecs: 3438
# There are 250 total trials across all .tif files.
# Frame indices are NOT block indexed
# ... N frames to align: 3375
# ... N unique frames: 3375
# ... File: 4 (has 3438 frames)
# ... asking for 13 extra frames...
# ... Last frame to align: 3451 (N frames total, 3438)
# ... N tstamps: 3438
# ... padding trial tstamps array... (should be 3375)
# N frames per trial: 135
# N tstamps: 3375
# N trials in block: 25
# ('Excluding:', [u'filehash', u'filepath'])
# ... processing trace type: neuropil
# ('drift offset:', 403.81397216540552)
# Showing initial drift correction (quantile: 0.10)
# Min value for all ROIs: -119.15683733
# ... processing trace type: np_subtracted
# ('drift offset:', -7.4004340487206521)
# Showing initial drift correction (quantile: 0.10)
# Min value for all ROIs: -307.324712944
# ... processing trace type: raw
# ('drift offset:', 298.06889399737281)
# Showing initial drift correction (quantile: 0.10)
# Min value for all ROIs: -351.016992188
# STIM TYPE: image
# **** File 26 of 60 *****
# *** Excluding: []
# /n/coxfs01/2p-data/JC099/20190609/FOV1_zoom2p0x/blobs_run3
# N tsecs: 3438
# There are 250 total trials across all .tif files.
# Frame indices are NOT block indexed
# ... N frames to align: 3375
# ... N unique frames: 3375
# ... File: 5 (has 3438 frames)
# ... asking for 13 extra frames...
# ... Last frame to align: 3451 (N frames total, 3438)
# ... N tstamps: 3438
# ... padding trial tstamps array... (should be 3375)
# N frames per trial: 135
# N tstamps: 3375
# N trials in block: 25
# ('Excluding:', [u'filehash', u'filepath'])
# ... processing trace type: neuropil
# ('drift offset:', 413.12140176723199)
# Showing initial drift correction (quantile: 0.10)
# Min value for all ROIs: -125.730604765
# ... processing trace type: np_subtracted
# ('drift offset:', 12.239049080139093)
# Showing initial drift correction (quantile: 0.10)
# Min value for all ROIs: -289.006988844
# ... processing trace type: raw
# ('drift offset:', 324.48751216984789)
# Showing initial drift correction (quantile: 0.10)
# Min value for all ROIs: -267.631896973
# STIM TYPE: image
# **** File 27 of 60 *****
# *** Excluding: []
# /n/coxfs01/2p-data/JC099/20190609/FOV1_zoom2p0x/blobs_run3
# N tsecs: 3438
# There are 250 total trials across all .tif files.
# Frame indices are NOT block indexed
# ... N frames to align: 3375
# ... N unique frames: 3375
# ... File: 6 (has 3438 frames)
# ... asking for 14 extra frames...
# ... Last frame to align: 3452 (N frames total, 3438)
# ... N tstamps: 3438
# ... padding trial tstamps array... (should be 3375)
# N frames per trial: 135
# N tstamps: 3375
# N trials in block: 25
# ('Excluding:', [u'filehash', u'filepath'])
# ... processing trace type: neuropil
# ('drift offset:', 403.61984734507553)
# Showing initial drift correction (quantile: 0.10)
# Min value for all ROIs: -117.917263844
# ... processing trace type: np_subtracted
# ('drift offset:', 5.1010154244953556)
# Showing initial drift correction (quantile: 0.10)
# Min value for all ROIs: -395.213190922
# ... processing trace type: raw
# ('drift offset:', 311.29979752893632)
# Showing initial drift correction (quantile: 0.10)
# Min value for all ROIs: -354.599264706
# STIM TYPE: image
# **** File 28 of 60 *****
# *** Excluding: []
# /n/coxfs01/2p-data/JC099/20190609/FOV1_zoom2p0x/blobs_run3
# N tsecs: 3438
# There are 250 total trials across all .tif files.
# Frame indices are NOT block indexed
# ... N frames to align: 3375
# ... N unique frames: 3375
# ... File: 7 (has 3438 frames)
# ... asking for 13 extra frames...
# ... Last frame to align: 3451 (N frames total, 3438)
# ... N tstamps: 3438
# ... padding trial tstamps array... (should be 3375)
# N frames per trial: 135
# N tstamps: 3375
# N trials in block: 25
# ('Excluding:', [u'filehash', u'filepath'])
# ... processing trace type: neuropil
# ('drift offset:', 390.79910706073827)
# Showing initial drift correction (quantile: 0.10)
# Min value for all ROIs: -113.383628589
# ... processing trace type: np_subtracted
# ('drift offset:', 4.8409871235010788)
# Showing initial drift correction (quantile: 0.10)
# Min value for all ROIs: -288.951066693
# ... processing trace type: raw
# ('drift offset:', 300.61358078579957)
# Showing initial drift correction (quantile: 0.10)
# Min value for all ROIs: -325.905678354
# STIM TYPE: image
# **** File 29 of 60 *****
# *** Excluding: []
# /n/coxfs01/2p-data/JC099/20190609/FOV1_zoom2p0x/blobs_run3
# N tsecs: 3438
# There are 250 total trials across all .tif files.
# Frame indices are NOT block indexed
# ... N frames to align: 3375
# ... N unique frames: 3375
# ... File: 8 (has 3438 frames)
# ... asking for 13 extra frames...
# ... Last frame to align: 3451 (N frames total, 3438)
# ... N tstamps: 3438
# ... padding trial tstamps array... (should be 3375)
# N frames per trial: 135
# N tstamps: 3375
# N trials in block: 25
# ('Excluding:', [u'filehash', u'filepath'])
# ... processing trace type: neuropil
# ('drift offset:', 397.18704168714589)
# Showing initial drift correction (quantile: 0.10)
# Min value for all ROIs: -122.111040609
# ... processing trace type: np_subtracted
# ('drift offset:', 113.09377201250069)
# Showing initial drift correction (quantile: 0.10)
# Min value for all ROIs: -409.960373066
# ... processing trace type: raw
# ('drift offset:', 412.89318388594694)
# Showing initial drift correction (quantile: 0.10)
# Min value for all ROIs: -415.208333333
# STIM TYPE: image
# **** File 30 of 60 *****
# *** Excluding: []
# /n/coxfs01/2p-data/JC099/20190609/FOV1_zoom2p0x/blobs_run3
# N tsecs: 3438
# There are 250 total trials across all .tif files.
# Frame indices are NOT block indexed
# ... N frames to align: 3375
# ... N unique frames: 3375
# ... File: 9 (has 3438 frames)
# ... asking for 13 extra frames...
# ... Last frame to align: 3451 (N frames total, 3438)
# ... N tstamps: 3438
# ... padding trial tstamps array... (should be 3375)
# N frames per trial: 135
# N tstamps: 3375
# N trials in block: 25
# ('Excluding:', [u'filehash', u'filepath'])
# ... processing trace type: neuropil
# ('drift offset:', 415.84070442400963)
# Showing initial drift correction (quantile: 0.10)
# Min value for all ROIs: -91.3140703518
# ... processing trace type: np_subtracted
# ('drift offset:', -8.3649534410196331)
# Showing initial drift correction (quantile: 0.10)
# Min value for all ROIs: -264.638384563
# ... processing trace type: raw
# ('drift offset:', 304.88738694917265)
# Showing initial drift correction (quantile: 0.10)
# Min value for all ROIs: -299.66073331
# STIM TYPE: image
# **** File 31 of 60 *****
# *** Excluding: []
# /n/coxfs01/2p-data/JC099/20190609/FOV1_zoom2p0x/blobs_run4
# N tsecs: 3438
# There are 250 total trials across all .tif files.
# Frame indices are NOT block indexed
# ... N frames to align: 3375
# ... N unique frames: 3375
# ... File: 0 (has 3438 frames)
# ... asking for 14 extra frames...
# ... Last frame to align: 3452 (N frames total, 3438)
# ... N tstamps: 3438
# ... padding trial tstamps array... (should be 3375)
# N frames per trial: 135
# N tstamps: 3375
# N trials in block: 25
# ('Excluding:', [u'filehash', u'filepath'])
# ... processing trace type: neuropil
# ('drift offset:', 547.82386480182595)
# Showing initial drift correction (quantile: 0.10)
# Min value for all ROIs: -185.345977763
# ... processing trace type: np_subtracted
# ('drift offset:', 2.5752195104289899)
# Showing initial drift correction (quantile: 0.10)
# Min value for all ROIs: -369.6670116
# ... processing trace type: raw
# ('drift offset:', 412.97149743873132)
# Showing initial drift correction (quantile: 0.10)
# Min value for all ROIs: -337.526295732
# STIM TYPE: image
# **** File 32 of 60 *****
# *** Excluding: []
# /n/coxfs01/2p-data/JC099/20190609/FOV1_zoom2p0x/blobs_run4
# N tsecs: 3438
# There are 250 total trials across all .tif files.
# Frame indices are NOT block indexed
# ... N frames to align: 3375
# ... N unique frames: 3375
# ... File: 1 (has 3438 frames)
# ... asking for 14 extra frames...
# ... Last frame to align: 3452 (N frames total, 3438)
# ... N tstamps: 3438
# ... padding trial tstamps array... (should be 3375)
# N frames per trial: 135
# N tstamps: 3375
# N trials in block: 25
# ('Excluding:', [u'filehash', u'filepath'])
# ... processing trace type: neuropil
# ('drift offset:', 552.51335661433359)
# Showing initial drift correction (quantile: 0.10)
# Min value for all ROIs: -210.909898477
# ... processing trace type: np_subtracted
# ('drift offset:', 3.2673362081407409)
# Showing initial drift correction (quantile: 0.10)
# Min value for all ROIs: -370.050511871
# ... processing trace type: raw
# ('drift offset:', 419.22292816899295)
# Showing initial drift correction (quantile: 0.10)
# Min value for all ROIs: -475.47418064
# STIM TYPE: image
# **** File 33 of 60 *****
# *** Excluding: []
# /n/coxfs01/2p-data/JC099/20190609/FOV1_zoom2p0x/blobs_run4
# N tsecs: 3438
# There are 250 total trials across all .tif files.
# Frame indices are NOT block indexed
# ... N frames to align: 3375
# ... N unique frames: 3375
# ... File: 2 (has 3438 frames)
# ... asking for 13 extra frames...
# ... Last frame to align: 3451 (N frames total, 3438)
# ... N tstamps: 3438
# ... padding trial tstamps array... (should be 3375)
# N frames per trial: 135
# N tstamps: 3375
# N trials in block: 25
# ('Excluding:', [u'filehash', u'filepath'])
# ... processing trace type: neuropil
# ('drift offset:', 535.33513549354484)
# Showing initial drift correction (quantile: 0.10)
# Min value for all ROIs: -232.583756345
# ... processing trace type: np_subtracted
# ('drift offset:', -1.6895674626685901)
# Showing initial drift correction (quantile: 0.10)
# Min value for all ROIs: -315.97922479
# ... processing trace type: raw
# ('drift offset:', 398.58680255501201)
# Showing initial drift correction (quantile: 0.10)
# Min value for all ROIs: -341.743616616
# STIM TYPE: image
# **** File 34 of 60 *****
# *** Excluding: []
# /n/coxfs01/2p-data/JC099/20190609/FOV1_zoom2p0x/blobs_run4
# N tsecs: 3438
# There are 250 total trials across all .tif files.
# Frame indices are NOT block indexed
# ... N frames to align: 3375
# ... N unique frames: 3375
# ... File: 3 (has 3438 frames)
# ... asking for 13 extra frames...
# ... Last frame to align: 3451 (N frames total, 3438)
# ... N tstamps: 3438
# ... padding trial tstamps array... (should be 3375)
# N frames per trial: 135
# N tstamps: 3375
# N trials in block: 25
# ('Excluding:', [u'filehash', u'filepath'])
# ... processing trace type: neuropil
# ('drift offset:', 539.17977940385697)
# Showing initial drift correction (quantile: 0.10)
# Min value for all ROIs: -157.089285714
# ... processing trace type: np_subtracted
# ('drift offset:', -1.5203136530668486)
# Showing initial drift correction (quantile: 0.10)
# Min value for all ROIs: -354.489768468
# ... processing trace type: raw
# ('drift offset:', 402.25336749151688)
# Showing initial drift correction (quantile: 0.10)
# Min value for all ROIs: -411.603110709
# STIM TYPE: image
# **** File 35 of 60 *****
# *** Excluding: []
# /n/coxfs01/2p-data/JC099/20190609/FOV1_zoom2p0x/blobs_run4
# N tsecs: 3438
# There are 250 total trials across all .tif files.
# Frame indices are NOT block indexed
# ... N frames to align: 3375
# ... N unique frames: 3375
# ... File: 4 (has 3438 frames)
# ... asking for 14 extra frames...
# ... Last frame to align: 3452 (N frames total, 3438)
# ... N tstamps: 3438
# ... padding trial tstamps array... (should be 3375)
# N frames per trial: 135
# N tstamps: 3375
# N trials in block: 25
# ('Excluding:', [u'filehash', u'filepath'])
# ... processing trace type: neuropil
# ('drift offset:', 536.19105279827625)
# Showing initial drift correction (quantile: 0.10)
# Min value for all ROIs: -157.596446701
# ... processing trace type: np_subtracted
# ('drift offset:', -3.0048343109979285)
# Showing initial drift correction (quantile: 0.10)
# Min value for all ROIs: -315.473068595
# ... processing trace type: raw
# ('drift offset:', 399.14541693793569)
# Showing initial drift correction (quantile: 0.10)
# Min value for all ROIs: -327.86328125
# STIM TYPE: image
# **** File 36 of 60 *****
# *** Excluding: []
# /n/coxfs01/2p-data/JC099/20190609/FOV1_zoom2p0x/blobs_run4
# N tsecs: 3438
# There are 250 total trials across all .tif files.
# Frame indices are NOT block indexed
# ... N frames to align: 3375
# ... N unique frames: 3375
# ... File: 5 (has 3438 frames)
# ... asking for 13 extra frames...
# ... Last frame to align: 3451 (N frames total, 3438)
# ... N tstamps: 3438
# ... padding trial tstamps array... (should be 3375)
# N frames per trial: 135
# N tstamps: 3375
# N trials in block: 25
# ('Excluding:', [u'filehash', u'filepath'])
# ... processing trace type: neuropil
# ('drift offset:', 564.83699501956698)
# Showing initial drift correction (quantile: 0.10)
# Min value for all ROIs: -1125.61942578
# ... processing trace type: np_subtracted
# ('drift offset:', 0.15543629585851684)
# Showing initial drift correction (quantile: 0.10)
# Min value for all ROIs: -416.446576749
# ... processing trace type: raw
# ('drift offset:', 424.92568263711598)
# Showing initial drift correction (quantile: 0.10)
# Min value for all ROIs: -1152.04358803
# STIM TYPE: image
# **** File 37 of 60 *****
# *** Excluding: []
# /n/coxfs01/2p-data/JC099/20190609/FOV1_zoom2p0x/blobs_run4
# N tsecs: 3438
# There are 250 total trials across all .tif files.
# Frame indices are NOT block indexed
# ... N frames to align: 3375
# ... N unique frames: 3375
# ... File: 6 (has 3438 frames)
# ... asking for 13 extra frames...
# ... Last frame to align: 3451 (N frames total, 3438)
# ... N tstamps: 3438
# ... padding trial tstamps array... (should be 3375)
# N frames per trial: 135
# N tstamps: 3375
# N trials in block: 25
# ('Excluding:', [u'filehash', u'filepath'])
# ... processing trace type: neuropil
# ('drift offset:', 533.42670788243754)
# Showing initial drift correction (quantile: 0.10)
# Min value for all ROIs: -163.312182741
# ... processing trace type: np_subtracted
# ('drift offset:', -4.0679947723924732)
# Showing initial drift correction (quantile: 0.10)
# Min value for all ROIs: -319.135816448
# ... processing trace type: raw
# ('drift offset:', 394.00911080180708)
# Showing initial drift correction (quantile: 0.10)
# Min value for all ROIs: -309.682250977
# STIM TYPE: image
# **** File 38 of 60 *****
# *** Excluding: []
# /n/coxfs01/2p-data/JC099/20190609/FOV1_zoom2p0x/blobs_run4
# N tsecs: 3438
# There are 250 total trials across all .tif files.
# Frame indices are NOT block indexed
# ... N frames to align: 3375
# ... N unique frames: 3375
# ... File: 7 (has 3438 frames)
# ... asking for 13 extra frames...
# ... Last frame to align: 3451 (N frames total, 3438)
# ... N tstamps: 3438
# ... padding trial tstamps array... (should be 3375)
# N frames per trial: 135
# N tstamps: 3375
# N trials in block: 25
# ('Excluding:', [u'filehash', u'filepath'])
# ... processing trace type: neuropil
# ('drift offset:', 462.75141352540032)
# Showing initial drift correction (quantile: 0.10)
# Min value for all ROIs: -138.908309456
# ... processing trace type: np_subtracted
# ('drift offset:', -7.879025687649813)
# Showing initial drift correction (quantile: 0.10)
# Min value for all ROIs: -383.744192708
# ... processing trace type: raw
# ('drift offset:', 337.30458952258448)
# Showing initial drift correction (quantile: 0.10)
# Min value for all ROIs: -393.872455798
# STIM TYPE: image
# **** File 39 of 60 *****
# *** Excluding: []
# /n/coxfs01/2p-data/JC099/20190609/FOV1_zoom2p0x/blobs_run4
# N tsecs: 3438
# There are 250 total trials across all .tif files.
# Frame indices are NOT block indexed
# ... N frames to align: 3375
# ... N unique frames: 3375
# ... File: 8 (has 3438 frames)
# ... asking for 14 extra frames...
# ... Last frame to align: 3452 (N frames total, 3438)
# ... N tstamps: 3438
# ... padding trial tstamps array... (should be 3375)
# N frames per trial: 135
# N tstamps: 3375
# N trials in block: 25
# ('Excluding:', [u'filehash', u'filepath'])
# ... processing trace type: neuropil
# ('drift offset:', 469.52839882358484)
# Showing initial drift correction (quantile: 0.10)
# Min value for all ROIs: -151.934025657
# ... processing trace type: np_subtracted
# /home/julianarhee/Repositories/2p-pipeline/pipeline/python/traces/trial_alignment.py:454: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   currdf['ix'] = [total_ix for _ in range(currdf.shape[0])]
# /home/julianarhee/Repositories/2p-pipeline/pipeline/python/traces/trial_alignment.py:458: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   currf0['ix'] = [total_ix for _ in range(currdf.shape[0])]
# ('drift offset:', -10.109934301961443)
# Showing initial drift correction (quantile: 0.10)
# Min value for all ROIs: -313.737607186
# ... processing trace type: raw
# ('drift offset:', 341.01869275902033)
# Showing initial drift correction (quantile: 0.10)
# Min value for all ROIs: -388.190943668
# STIM TYPE: image
# **** File 40 of 60 *****
# *** Excluding: []
# /n/coxfs01/2p-data/JC099/20190609/FOV1_zoom2p0x/blobs_run4
# N tsecs: 3438
# There are 250 total trials across all .tif files.
# Frame indices are NOT block indexed
# ... N frames to align: 3375
# ... N unique frames: 3375
# ... File: 9 (has 3438 frames)
# ... asking for 13 extra frames...
# ... Last frame to align: 3451 (N frames total, 3438)
# ... N tstamps: 3438
# ... padding trial tstamps array... (should be 3375)
# N frames per trial: 135
# N tstamps: 3375
# N trials in block: 25
# ('Excluding:', [u'filehash', u'filepath'])
# ... processing trace type: neuropil
# ('drift offset:', 501.96542012383287)
# Showing initial drift correction (quantile: 0.10)
# Min value for all ROIs: -192.01170275
# ... processing trace type: np_subtracted
# ('drift offset:', -9.7774933244268709)
# Showing initial drift correction (quantile: 0.10)
# Min value for all ROIs: -642.620196369
# ... processing trace type: raw
# ('drift offset:', 366.6524811172257)
# Showing initial drift correction (quantile: 0.10)
# Min value for all ROIs: -382.243896484
# STIM TYPE: image
# **** File 41 of 60 *****
# *** Excluding: []
# /n/coxfs01/2p-data/JC099/20190609/FOV1_zoom2p0x/blobs_run5
# N tsecs: 3438
# There are 250 total trials across all .tif files.
# Frame indices are NOT block indexed
# ... N frames to align: 3375
# ... N unique frames: 3375
# ... File: 0 (has 3438 frames)
# ... asking for 13 extra frames...
# ... Last frame to align: 3451 (N frames total, 3438)
# ... N tstamps: 3438
# ... padding trial tstamps array... (should be 3375)
# N frames per trial: 135
# N tstamps: 3375
# N trials in block: 25
# ('Excluding:', [u'filehash', u'filepath'])
# ... processing trace type: neuropil
# ('drift offset:', 518.56262046141273)
# Showing initial drift correction (quantile: 0.10)
# Min value for all ROIs: -159.186875
# ... processing trace type: np_subtracted
# ('drift offset:', -6.583023610518711)
# Showing initial drift correction (quantile: 0.10)
# Min value for all ROIs: -473.215568203
# ... processing trace type: raw
# ('drift offset:', 381.66026467284718)
# Showing initial drift correction (quantile: 0.10)
# Min value for all ROIs: -586.094152114
# STIM TYPE: image
# **** File 42 of 60 *****
# *** Excluding: []
# /n/coxfs01/2p-data/JC099/20190609/FOV1_zoom2p0x/blobs_run5
# N tsecs: 3438
# There are 250 total trials across all .tif files.
# Frame indices are NOT block indexed
# ... N frames to align: 3375
# ... N unique frames: 3375
# ... File: 1 (has 3438 frames)
# ... asking for 13 extra frames...
# ... Last frame to align: 3451 (N frames total, 3438)
# ... N tstamps: 3438
# ... padding trial tstamps array... (should be 3375)
# N frames per trial: 135
# N tstamps: 3375
# N trials in block: 25
# ('Excluding:', [u'filehash', u'filepath'])
# ... processing trace type: neuropil
# ('drift offset:', 496.17404647030492)
# Showing initial drift correction (quantile: 0.10)
# Min value for all ROIs: -148.054568528
# ... processing trace type: np_subtracted
# ('drift offset:', -10.082891642320687)
# Showing initial drift correction (quantile: 0.10)
# Min value for all ROIs: -400.976231094
# ... processing trace type: raw
# ('drift offset:', 364.06240292599358)
# Showing initial drift correction (quantile: 0.10)
# Min value for all ROIs: -380.268102134
# STIM TYPE: image
# **** File 43 of 60 *****
# *** Excluding: []
# /n/coxfs01/2p-data/JC099/20190609/FOV1_zoom2p0x/blobs_run5
# N tsecs: 3438
# There are 250 total trials across all .tif files.
# Frame indices are NOT block indexed
# ... N frames to align: 3375
# ... N unique frames: 3375
# ... File: 2 (has 3438 frames)
# ... asking for 14 extra frames...
# ... Last frame to align: 3452 (N frames total, 3438)
# ... N tstamps: 3438
# ... padding trial tstamps array... (should be 3375)
# N frames per trial: 135
# N tstamps: 3375
# N trials in block: 25
# ('Excluding:', [u'filehash', u'filepath'])
# ... processing trace type: neuropil
# ('drift offset:', 484.8528772436693)
# Showing initial drift correction (quantile: 0.10)
# Min value for all ROIs: -115.20748731
# ... processing trace type: np_subtracted
# ('drift offset:', -11.188494899090378)
# Showing initial drift correction (quantile: 0.10)
# Min value for all ROIs: -285.344480774
# ... processing trace type: raw
# ('drift offset:', 351.86228894027232)
# Showing initial drift correction (quantile: 0.10)
# Min value for all ROIs: -297.170231517
# STIM TYPE: image
# **** File 44 of 60 *****
# *** Excluding: []
# /n/coxfs01/2p-data/JC099/20190609/FOV1_zoom2p0x/blobs_run5
# N tsecs: 3438
# There are 250 total trials across all .tif files.
# Frame indices are NOT block indexed
# ... N frames to align: 3375
# ... N unique frames: 3375
# ... File: 3 (has 3438 frames)
# ... asking for 13 extra frames...
# ... Last frame to align: 3451 (N frames total, 3438)
# ... N tstamps: 3438
# ... padding trial tstamps array... (should be 3375)
# N frames per trial: 135
# N tstamps: 3375
# N trials in block: 25
# ('Excluding:', [u'filehash', u'filepath'])
# ... processing trace type: neuropil
# ('drift offset:', 484.24720611942183)
# Showing initial drift correction (quantile: 0.10)
# Min value for all ROIs: -145.635308491
# ... processing trace type: np_subtracted
# ('drift offset:', -7.8619327344409129)
# Showing initial drift correction (quantile: 0.10)
# Min value for all ROIs: -307.374834897
# ... processing trace type: raw
# ('drift offset:', 356.45281802441798)
# Showing initial drift correction (quantile: 0.10)
# Min value for all ROIs: -344.115806021
# STIM TYPE: image
# **** File 45 of 60 *****
# *** Excluding: []
# /n/coxfs01/2p-data/JC099/20190609/FOV1_zoom2p0x/blobs_run5
# N tsecs: 3438
# There are 250 total trials across all .tif files.
# ...
# **** File 47 of 60 *****
# *** Excluding: []
# /n/coxfs01/2p-data/JC099/20190609/FOV1_zoom2p0x/blobs_run5
# N tsecs: 3438
# There are 250 total trials across all .tif files.
# Frame indices are NOT block indexed
# ... N frames to align: 3375
# ... N unique frames: 3375
# ... File: 6 (has 3438 frames)
# ... asking for 13 extra frames...
# ... Last frame to align: 3451 (N frames total, 3438)
# ... N tstamps: 3438
# ... padding trial tstamps array... (should be 3375)
# N frames per trial: 135
# N tstamps: 3375
# N trials in block: 25
# ('Excluding:', [u'filehash', u'filepath'])
# ... processing trace type: neuropil
# ('drift offset:', 493.23456552704442)
# Showing initial drift correction (quantile: 0.10)
# Min value for all ROIs: -140.072969543
# ... processing trace type: np_subtracted
# ('drift offset:', -10.778578468107046)
# Showing initial drift correction (quantile: 0.10)
# Min value for all ROIs: -342.416518018
# ... processing trace type: raw
# ('drift offset:', 357.43233653399642)
# Showing initial drift correction (quantile: 0.10)
# Min value for all ROIs: -347.391720655
# STIM TYPE: image
# **** File 48 of 60 *****
# *** Excluding: []
# /n/coxfs01/2p-data/JC099/20190609/FOV1_zoom2p0x/blobs_run5
# N tsecs: 3438
# There are 250 total trials across all .tif files.
# Frame indices are NOT block indexed
# ... N frames to align: 3375
# ... N unique frames: 3375
# ... File: 7 (has 3438 frames)
# ... asking for 14 extra frames...
# ... Last frame to align: 3452 (N frames total, 3438)
# ... N tstamps: 3438
# ... padding trial tstamps array... (should be 3375)
# N frames per trial: 135
# N tstamps: 3375
# N trials in block: 25
# ('Excluding:', [u'filehash', u'filepath'])
# ... processing trace type: neuropil
# ('drift offset:', 489.8292735076447)
# Showing initial drift correction (quantile: 0.10)
# Min value for all ROIs: -134.85215736
# ... processing trace type: np_subtracted
# ('drift offset:', -10.436630002989142)
# Showing initial drift correction (quantile: 0.10)
# Min value for all ROIs: -293.132182606
# ... processing trace type: raw
# ('drift offset:', 355.88061875413882)
# Showing initial drift correction (quantile: 0.10)
# Min value for all ROIs: -350.946265244
# STIM TYPE: image
# **** File 49 of 60 *****
# *** Excluding: []
# /n/coxfs01/2p-data/JC099/20190609/FOV1_zoom2p0x/blobs_run5
# N tsecs: 3438
# There are 250 total trials across all .tif files.
# Frame indices are NOT block indexed
# ... N frames to align: 3375
# ... N unique frames: 3375
# ... File: 8 (has 3438 frames)
# ... asking for 13 extra frames...
# ... Last frame to align: 3451 (N frames total, 3438)
# ... N tstamps: 3438
# ... padding trial tstamps array... (should be 3375)
# N frames per trial: 135
# N tstamps: 3375
# N trials in block: 25
# ('Excluding:', [u'filehash', u'filepath'])
# ... processing trace type: neuropil
# ('drift offset:', 497.15333681012225)
# Showing initial drift correction (quantile: 0.10)
# Min value for all ROIs: -189.246192893
# ... processing trace type: np_subtracted
# ('drift offset:', -9.1613891349495589)
# Showing initial drift correction (quantile: 0.10)
# Min value for all ROIs: -306.004913644
# ... processing trace type: raw
# ('drift offset:', 364.7438299845)
# Showing initial drift correction (quantile: 0.10)
# Min value for all ROIs: -324.385766006
# STIM TYPE: image
# **** File 50 of 60 *****
# *** Excluding: []
# /n/coxfs01/2p-data/JC099/20190609/FOV1_zoom2p0x/blobs_run5
# N tsecs: 3438
# There are 250 total trials across all .tif files.
# Frame indices are NOT block indexed
# ... N frames to align: 3375
# ... N unique frames: 3375
# ... File: 9 (has 3438 frames)
# ... asking for 13 extra frames...
# ... Last frame to align: 3451 (N frames total, 3438)
# ... N tstamps: 3438
# ... padding trial tstamps array... (should be 3375)
# N frames per trial: 135
# N tstamps: 3375
# N trials in block: 25
# ('Excluding:', [u'filehash', u'filepath'])
# ... processing trace type: neuropil
# ('drift offset:', 494.18841261052097)
# Showing initial drift correction (quantile: 0.10)
# Min value for all ROIs: -118.542261905
# ... processing trace type: np_subtracted
# ('drift offset:', -7.6075950970396713)
# Showing initial drift correction (quantile: 0.10)
# Min value for all ROIs: -341.726805133
# ... processing trace type: raw
# ('drift offset:', 361.43363220599065)
# Showing initial drift correction (quantile: 0.10)
# Min value for all ROIs: -316.932617188
# STIM TYPE: image
# **** File 51 of 60 *****
# *** Excluding: []
# /n/coxfs01/2p-data/JC099/20190609/FOV1_zoom2p0x/blobs_run6
# N tsecs: 3438
# There are 250 total trials across all .tif files.
# Frame indices are NOT block indexed
# ... N frames to align: 3375
# ... N unique frames: 3375
# ... File: 0 (has 3438 frames)
# ... asking for 14 extra frames...
# ... Last frame to align: 3452 (N frames total, 3438)
# ... N tstamps: 3438
# ... padding trial tstamps array... (should be 3375)
# N frames per trial: 135
# N tstamps: 3375
# N trials in block: 25
# ('Excluding:', [u'filehash', u'filepath'])
# ... processing trace type: neuropil
# ('drift offset:', 483.66673888797385)
# Showing initial drift correction (quantile: 0.10)
# Min value for all ROIs: -191.079949239
# ... processing trace type: np_subtracted
# ('drift offset:', -10.970823730191903)
# Showing initial drift correction (quantile: 0.10)
# Min value for all ROIs: -405.947585655
# ... processing trace type: raw
# ('drift offset:', 353.2953807606238)
# Showing initial drift correction (quantile: 0.10)
# Min value for all ROIs: -333.847036966
# STIM TYPE: image
# **** File 52 of 60 *****
# *** Excluding: []
# /n/coxfs01/2p-data/JC099/20190609/FOV1_zoom2p0x/blobs_run6
# N tsecs: 3438
# There are 250 total trials across all .tif files.
# Frame indices are NOT block indexed
# ... N frames to align: 3375
# ... N unique frames: 3375
# ... File: 1 (has 3438 frames)
# ... asking for 13 extra frames...
# ... Last frame to align: 3451 (N frames total, 3438)
# ... N tstamps: 3438
# ... padding trial tstamps array... (should be 3375)
# N frames per trial: 135
# N tstamps: 3375
# N trials in block: 25
# ('Excluding:', [u'filehash', u'filepath'])
# ... processing trace type: neuropil
# ('drift offset:', 482.55757525359616)
# Showing initial drift correction (quantile: 0.10)
# Min value for all ROIs: -175.789974619
# ... processing trace type: np_subtracted
# ('drift offset:', -7.8724676181165352)
# Showing initial drift correction (quantile: 0.10)
# Min value for all ROIs: -326.66540499
# ... processing trace type: raw
# ('drift offset:', 354.24180712194976)
# Showing initial drift correction (quantile: 0.10)
# Min value for all ROIs: -384.100895579
# STIM TYPE: image
# **** File 53 of 60 *****
# *** Excluding: []
# /n/coxfs01/2p-data/JC099/20190609/FOV1_zoom2p0x/blobs_run6
# N tsecs: 3438
# There are 250 total trials across all .tif files.
# Frame indices are NOT block indexed
# ... N frames to align: 3375
# ... N unique frames: 3375
# ... File: 2 (has 3438 frames)
# ... asking for 13 extra frames...
# ... Last frame to align: 3451 (N frames total, 3438)
# ... N tstamps: 3438
# ... padding trial tstamps array... (should be 3375)
# N frames per trial: 135
# N tstamps: 3375
# N trials in block: 25
# ('Excluding:', [u'filehash', u'filepath'])
# ... processing trace type: neuropil
# ('drift offset:', 492.81375826394026)
# Showing initial drift correction (quantile: 0.10)
# Min value for all ROIs: -133.391959799
# ... processing trace type: np_subtracted
# ('drift offset:', -9.7587249803386449)
# Showing initial drift correction (quantile: 0.10)
# Min value for all ROIs: -318.852784337
# ... processing trace type: raw
# ('drift offset:', 359.16324546584923)
# Showing initial drift correction (quantile: 0.10)
# Min value for all ROIs: -345.773670015
# STIM TYPE: image
# **** File 54 of 60 *****
# *** Excluding: []
# /n/coxfs01/2p-data/JC099/20190609/FOV1_zoom2p0x/blobs_run6
# N tsecs: 3438
# There are 250 total trials across all .tif files.
# Frame indices are NOT block indexed
# ... N frames to align: 3375
# ... N unique frames: 3375
# ... File: 3 (has 3438 frames)
# ... asking for 13 extra frames...
# ... Last frame to align: 3451 (N frames total, 3438)
# ... N tstamps: 3438
# ... padding trial tstamps array... (should be 3375)
# N frames per trial: 135
# N tstamps: 3375
# N trials in block: 25
# ('Excluding:', [u'filehash', u'filepath'])
# ... processing trace type: neuropil
# ('drift offset:', 481.66884798961041)
# Showing initial drift correction (quantile: 0.10)
# Min value for all ROIs: -128.625628141
# ... processing trace type: np_subtracted
# ('drift offset:', -8.2225857596177594)
# Showing initial drift correction (quantile: 0.10)
# Min value for all ROIs: -287.378802861
# ... processing trace type: raw
# ('drift offset:', 351.53730320057531)
# Showing initial drift correction (quantile: 0.10)
# Min value for all ROIs: -339.084436928
# STIM TYPE: image
# **** File 55 of 60 *****
# *** Excluding: []
# /n/coxfs01/2p-data/JC099/20190609/FOV1_zoom2p0x/blobs_run6
# N tsecs: 3438
# There are 250 total trials across all .tif files.
# Frame indices are NOT block indexed
# ... N frames to align: 3375
# ... N unique frames: 3375
# ... File: 4 (has 3438 frames)
# ... asking for 13 extra frames...
# ... Last frame to align: 3451 (N frames total, 3438)
# ... N tstamps: 3438
# ... padding trial tstamps array... (should be 3375)
# N frames per trial: 135
# N tstamps: 3375
# N trials in block: 25
# ('Excluding:', [u'filehash', u'filepath'])
# ... processing trace type: neuropil
# ('drift offset:', 484.8190755630535)
# Showing initial drift correction (quantile: 0.10)
# Min value for all ROIs: -166.839467005
# ... processing trace type: np_subtracted
# ('drift offset:', -8.7318847501264454)
# Showing initial drift correction (quantile: 0.10)
# Min value for all ROIs: -298.800097076
# ... processing trace type: raw
# ('drift offset:', 352.86480354765388)
# Showing initial drift correction (quantile: 0.10)
# Min value for all ROIs: -331.136909299
# STIM TYPE: image
# **** File 56 of 60 *****
# *** Excluding: []
# /n/coxfs01/2p-data/JC099/20190609/FOV1_zoom2p0x/blobs_run6
# N tsecs: 3438
# There are 250 total trials across all .tif files.
# Frame indices are NOT block indexed
# ... N frames to align: 3375
# ... N unique frames: 3375
# ... File: 5 (has 3438 frames)
# ... asking for 14 extra frames...
# ... Last frame to align: 3452 (N frames total, 3438)
# ... N tstamps: 3438
# ... padding trial tstamps array... (should be 3375)
# N frames per trial: 135
# N tstamps: 3375
# N trials in block: 25
# ('Excluding:', [u'filehash', u'filepath'])
# ... processing trace type: neuropil
# ('drift offset:', 491.4095708110824)
# Showing initial drift correction (quantile: 0.10)
# Min value for all ROIs: -124.430485762
# ... processing trace type: np_subtracted
# ('drift offset:', -10.26805487893148)
# Showing initial drift correction (quantile: 0.10)
# Min value for all ROIs: -350.921194577
# ... processing trace type: raw
# ('drift offset:', 358.75063948920325)
# Showing initial drift correction (quantile: 0.10)
# Min value for all ROIs: -341.321551067
# STIM TYPE: image
# **** File 57 of 60 *****
# *** Excluding: []
# /n/coxfs01/2p-data/JC099/20190609/FOV1_zoom2p0x/blobs_run6
# N tsecs: 3438
# There are 250 total trials across all .tif files.
# Frame indices are NOT block indexed
# ... N frames to align: 3375
# ... N unique frames: 3375
# ... File: 6 (has 3438 frames)
# ... asking for 14 extra frames...
# ... Last frame to align: 3452 (N frames total, 3438)
# ... N tstamps: 3438
# ... padding trial tstamps array... (should be 3375)
# N frames per trial: 135
# N tstamps: 3375
# N trials in block: 25
# ('Excluding:', [u'filehash', u'filepath'])
# ... processing trace type: neuropil
# ('drift offset:', 478.7585931347636)
# Showing initial drift correction (quantile: 0.10)
# Min value for all ROIs: -129.868020305
# ... processing trace type: np_subtracted
# ('drift offset:', -9.8358289685309348)
# Showing initial drift correction (quantile: 0.10)
# Min value for all ROIs: -304.268967052
# ... processing trace type: raw
# ('drift offset:', 348.526927047301)
# Showing initial drift correction (quantile: 0.10)
# Min value for all ROIs: -305.064357851
# STIM TYPE: image
# **** File 58 of 60 *****
# *** Excluding: []
# /n/coxfs01/2p-data/JC099/20190609/FOV1_zoom2p0x/blobs_run6
# N tsecs: 3438
# There are 250 total trials across all .tif files.
# Frame indices are NOT block indexed
# ... N frames to align: 3375
# ... N unique frames: 3375
# ... File: 7 (has 3438 frames)
# ... asking for 13 extra frames...
# ... Last frame to align: 3451 (N frames total, 3438)
# ... N tstamps: 3438
# ... padding trial tstamps array... (should be 3375)
# N frames per trial: 135
# N tstamps: 3375
# N trials in block: 25
# ('Excluding:', [u'filehash', u'filepath'])
# ... processing trace type: neuropil
# ('drift offset:', 492.18993732652865)
# Showing initial drift correction (quantile: 0.10)
# Min value for all ROIs: -226.664242424
# ... processing trace type: np_subtracted
# ('drift offset:', -12.988568176040802)
# Showing initial drift correction (quantile: 0.10)
# Min value for all ROIs: -539.027646236
# ... processing trace type: raw
# ('drift offset:', 358.7707117401618)
# Showing initial drift correction (quantile: 0.10)
# Min value for all ROIs: -396.845717921
# STIM TYPE: image
# **** File 59 of 60 *****
# *** Excluding: []
# /n/coxfs01/2p-data/JC099/20190609/FOV1_zoom2p0x/blobs_run6
# N tsecs: 3438
# There are 250 total trials across all .tif files.
# Frame indices are NOT block indexed
# ... N frames to align: 3375
# ... N unique frames: 3375
# ... File: 8 (has 3438 frames)
# ... asking for 13 extra frames...
# ... Last frame to align: 3451 (N frames total, 3438)
# ... N tstamps: 3438
# ... padding trial tstamps array... (should be 3375)
# N frames per trial: 135
# N tstamps: 3375
# N trials in block: 25
# ('Excluding:', [u'filehash', u'filepath'])
# ... processing trace type: neuropil
# ('drift offset:', 471.19031223239159)
# Showing initial drift correction (quantile: 0.10)
# Min value for all ROIs: -700.067621777
# ... processing trace type: np_subtracted
# ('drift offset:', -10.929569891422361)
# Showing initial drift correction (quantile: 0.10)
# Min value for all ROIs: -389.604727333
# ... processing trace type: raw
# ('drift offset:', 343.94580117279355)
# Showing initial drift correction (quantile: 0.10)
# Min value for all ROIs: -783.93233817
# STIM TYPE: image
# **** File 60 of 60 *****
# *** Excluding: []
# /n/coxfs01/2p-data/JC099/20190609/FOV1_zoom2p0x/blobs_run6
# N tsecs: 3438
# There are 250 total trials across all .tif files.
# Frame indices are NOT block indexed
# ... N frames to align: 3375
# ... N unique frames: 3375
# ... File: 9 (has 3438 frames)
# ... asking for 14 extra frames...
# ... Last frame to align: 3452 (N frames total, 3438)
# ... N tstamps: 3438
# ... padding trial tstamps array... (should be 3375)
# N frames per trial: 135
# N tstamps: 3375
# N trials in block: 25
# ('Excluding:', [u'filehash', u'filepath'])
# ... processing trace type: neuropil
# ('drift offset:', 469.77671088912587)
# Showing initial drift correction (quantile: 0.10)
# Min value for all ROIs: -1305.22364412
# ... processing trace type: np_subtracted
# ('drift offset:', -12.433784732084103)
# Showing initial drift correction (quantile: 0.10)
# Min value for all ROIs: -568.939530863
# ... processing trace type: raw
# ('drift offset:', 342.66344192445587)
# Showing initial drift correction (quantile: 0.10)
# Min value for all ROIs: -1236.10727896
# STIM TYPE: image
# Nframes on: [45]
# stim_durs (sec): [1.0]
# XDATA concatenated: (202500, 312)
# ('*** LABELS:', (202500, 8))
# STIM TYPE: image
# Saving labels data... /n/coxfs01/2p-data/JC099/20190609/FOV1_zoom2p0x/combined_blobs_static/traces/traces001_2be711_traces001_333f6c_traces001_31bd42_traces001_0b8503_traces001_2d8e76_traces001_8fe19c/data_arrays/labels.npz
# neuropil
# Saving labels data... /n/coxfs01/2p-data/JC099/20190609/FOV1_zoom2p0x/combined_blobs_static/traces/traces001_2be711_traces001_333f6c_traces001_31bd42_traces001_0b8503_traces001_2d8e76_traces001_8fe19c/data_arrays/neuropil.npz
# np_subtracted
# Saving labels data... /n/coxfs01/2p-data/JC099/20190609/FOV1_zoom2p0x/combined_blobs_static/traces/traces001_2be711_traces001_333f6c_traces001_31bd42_traces001_0b8503_traces001_2d8e76_traces001_8fe19c/data_arrays/np_subtracted.npz
# raw
# Saving labels data... /n/coxfs01/2p-data/JC099/20190609/FOV1_zoom2p0x/combined_blobs_static/traces/traces001_2be711_traces001_333f6c_traces001_31bd42_traces001_0b8503_traces001_2d8e76_traces001_8fe19c/data_arrays/raw.npz
# *****corrected offsets!*****
# NP_subtracted offset was: -8.23
# adding NP offset... (NP baseline offset: 440.92)
# ((202500, 311), (311,), ())
# ... updating self
