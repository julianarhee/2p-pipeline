# %%
import numpy as np
import os
from scipy.misc import imread
import cPickle as pkl
import scipy.signal
import numpy.fft as fft
import sys
import optparse
from PIL import Image
import re
import itertools
from scipy import ndimage

import time
import datetime

import pandas as pd

from bokeh.io import gridplot, output_file, show
from bokeh.plotting import figure
import csv

import pymworks 
import pandas as pd
import operator
import codecs

import scipy.io
import copy# Abstract struct class       
class Struct:
    def __init__ (self, *argv, **argd):
        if len(argd):
            # Update by dictionary
            self.__dict__.update (argd)
        else:
            # Update by position
            attrs = filter (lambda x: x[0:2] != "__", dir(self))
            for n in range(len(argv)):
                setattr(self, attrs[n], argv[n])


class cycstruct(Struct):
    times = []
    idxs = 0
    vals = 0
    ordernum = 0
    triggers = 0

# %%
from bokeh.plotting import figure, show
from bokeh.io import output_notebook
output_notebook()
# Out:
#     <div class="bk-root">
#         <a href="http://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="0a1d85ee-dc85-403a-b4cb-7d47c18a6041">Loading BokehJS ...</span>
#     </div>

# %%
from parse_mw_events import get_bar_events

# %%
prepend = '/' #'/Users/julianarhee'
#source_dir = os.path.join(prepend,'nas/volume1/2photon/RESDATA/20170724_CE051/retinotopy1') #options.source_dir #'/nas/volume1/2photon/RESDATA/TEFO/20160118_AG33/fov1_gratings1'
#source_dir = os.path.join(prepend,'nas/volume1/2photon/RESDATA/test_triggers/timer') #options.source_dir #'/nas/volume1/2photon/RESDATA/TEFO/20160118_AG33/fov1_gratings1'
source_dir = os.path.join(prepend,'nas/volume1/2photon/RESDATA/20170811_CE052/retinotopy3') #options.source_dir #'/nas/volume1/2photon/RESDATA/TEFO/20160118_AG33/fov1_gratings1'

stimtype = 'bar' #options.stimtype #'grating'
mask = False #options.mask # False
long_trials = False #options.long_trials #True
no_ard = False #options.no_ard
frame_rate = 44.63 #85.14

# Look in child dir (of source_dir) to find mw_data paths:
mw_files = os.listdir(os.path.join(source_dir, 'mw_data'))
mw_files = [m for m in mw_files if m.endswith('.mwk')]

# %%
mwfile = mw_files[0]

fn_base = mwfile[:-4]
mw_data_dir = os.path.join(source_dir, 'mw_data')
mw_fn = fn_base+'.mwk'
dfn = os.path.join(mw_data_dir, mw_fn)
dfns = [dfn]

print "MW file: ", dfns
# Out:
# MW file:  ['/nas/volume1/2photon/RESDATA/20170811_CE052/retinotopy3/mw_data/20170811_CE052_run3.mwk']

# %%
if stimtype=='bar':
    pixelevents, stimevents, trigger_times, session_info = get_bar_events(dfns[0])
else:
    pixelevents, stimevents, trialevents, trigger_times, session_info = get_stimulus_events(dfns, stimtype=stimtype)
# Out:
# ****************************************************************
# Parsing file
# /nas/volume1/2photon/RESDATA/20170811_CE052/retinotopy3/mw_data/20170811_CE052_run3.mwk...
# Found 1 start events in session.
# Bounds:  [[457767409969, 458175153294]]
# bound ID: 0 407.743325 sec
# ****************************************************************
# ................................................................
# SECTION 0
# ................................................................
# Found > 1 name for frame-trigger:
# Choose:  ['frame_trigger_timeout', 'frame_trigger_on', 'trigger_received', 'trigger_active', 'frame_trigger']
# Hint: RSVP could be FrameTrigger, otherwise frame_trigger.
# Type var name to use: frame_trigger
# first on event:  Event[code=39, name=frame_trigger, time=457780845705, value=0]
# first off event:  Event[code=39, name=frame_trigger, time=457855277621, value=1]
# Duration of first run: 74.4319 sec.
# [Event[code=39, name=frame_trigger, time=457767410045, value=1], Event[code=39, name=frame_trigger, time=457780845705, value=0], Event[code=39, name=frame_trigger, time=457855277621, value=1], Event[code=39, name=frame_trigger, time=457887109605, value=0], Event[code=39, name=frame_trigger, time=457961557677, value=1], Event[code=39, name=frame_trigger, time=457990685630, value=0], Event[code=39, name=frame_trigger, time=458065141733, value=1], Event[code=39, name=frame_trigger, time=458098149676, value=0], Event[code=39, name=frame_trigger, time=458172597579, value=1], Event[code=39, name=frame_trigger, time=458175153216, value=1]]
# 2
# 4
# 4
# 6
# 6
# 8
# 8
# 9
# ........................................................................................
# Found 5 chunks from frame-on/-off triggers:
# ........................................................................................
# 0 :  74.431916
# 1 :  74.448072
# 2 :  74.456103
# 3 :  74.447903
# 4 :  2.555637
# ........................................................................................
# Select indices [EX: 0,1,2,4] of runs to include, or press <enter> to accept all:
# 0123
# Run: 0
# Run: 1
# Run: 2
# Run: 3
# Press <enter> to accept. Press 'r' to re-try.
# Selected 4 runs.
# selected runs: [0, 1, 2, 3]
# N pix-evs found in boundary: 17761
# Got 17760 pix code events for current session.
# 132
# Run 0 :  bottom
# Run 1 :  right
# Run 2 :  top
# Run 3 :  left
# Target frequency: 0.27 Hz, 20 cycles.
# Expected run duration: ~74.07 seconds.
# Found 4 runs.
# Run 0: 73.99 s.
# Run 1: 73.99 s.
# Run 2: 73.98 s.
# Run 3: 73.99 s.

# %%
print len(trigger_times)
print frame_rate
# Out:
# 4
# 44.63

# %%
print session_info
n_expected_triggers = (1./session_info['target_freq'])*session_info['ncycles']*frame_rate*len(trigger_times)
print "Expected {0:.2f} frame triggers.".format(n_expected_triggers)
# Out:
# {'ncycles': 20, 'barwidth': 2.5, 'target_freq': 0.27}
# Expected 13223.70 frame triggers.

# %%
no_ard = False

# %%
#if no_ard is False:
# --------------------------------------------------------------------
# ARDUINO codes:
# --------------------------------------------------------------------

ard_fn = fn_base+'.txt'
ard_data_dir = os.path.join(source_dir, 'ard_data')
ard_dfn = os.path.join(ard_data_dir, ard_fn)

f = codecs.open(ard_dfn, 'r')
data = f.read()
bad_end = False
if not data[-1]=='_':
   bad_end = True
packets = data.split('__')
nsplits = packets[0].count('*')
tmp_ard_evs = []
for pidx,packet in enumerate(packets):
    #print pidx
    if pidx==0:
        packet = packet[1:]
    elif pidx==len(packets)-1:
        if bad_end is True:
          continue
        else:
          packet = packet[:-1]
    try:
        if nsplits == 2:
            pin = packet.split('*', 2)[0]
            tstring = packet.split('*', 2)[2]
        else:
            pin = packet.split('*', 1)[0]
            tstring = packet.split('*', 1)[1]
        try:
            pin_id = int(pin) #get_int(pin) #pin #int(pin)
            #pin_id = sum(ord(c) << (i * 8) for i, c in enumerate(pin[::-1]))
            tstamp = int(tstring) #sum(ord(c) << (i * 8) for i, c in enumerate(tstring[::-1]))
            tmp_ard_evs.append([pin_id, tstamp])
        except NameError as e:
            print pidx
            print pin_id
            print tstring

    except IndexError as e:
        print pidx
        print packet
print packets[0:5]
print nsplits
# Out:
# ['_0*0*59564076', '0*0*59565052', '0*0*59566096', '0*0*59567108', '0*0*59568152']
# 2

# %%
print len(packets)
# Out:
# 310923

# %%
# Get lists of arduino times and codes:
ard_times = np.array([i[1] for i in tmp_ard_evs])
ard_codes = np.array([i[0] for i in tmp_ard_evs])
print tmp_ard_evs[0:5]
# Out:
# [[0, 59564076], [0, 59565052], [0, 59566096], [0, 59567108], [0, 59568152]]

# %%
# Check for arduino roll-overs:
tdiffs = np.array(np.diff(ard_times))
rollover_idxs = [t for t in tdiffs if t<0] #np.where(tdiffs<0)
if any(rollover_idxs):
    print "Found rollover points!  Fix this..."

print rollover_idxs
# Out:
# []

# %%
# PLOT intervals:
tstamp_intervals = np.array(np.diff(ard_times))
print "N intervals:", len(tstamp_intervals)
print "min:", min(tstamp_intervals)
print "max:", max(tstamp_intervals)
print len([i for i,v in enumerate(tstamp_intervals) if v>15000])
p1 = figure(title="Intervals between frame-on triggers (us)",tools="save, zoom_in, zoom_out, pan",
            background_fill_color="white")

#medintervals = np.array([i for i in intervals if i<=10000000])

hist, edges = np.histogram(tstamp_intervals, density=True, bins=5000)
p1.quad(top=hist, bottom=0, left=edges[:-1], right=edges[1:],
        fill_color="#036564", line_color="#033649")
show(p1)
# Out:
# N intervals: 310921
# min: 976
# max: 1368
# 0
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="9a0d7680-8aee-494b-a3a9-520ede27bb4c"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         var el = document.getElementById("9a0d7680-8aee-494b-a3a9-520ede27bb4c");
#         el.textContent = "BokehJS " + Bokeh.version + " successfully loaded.";
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("9a0d7680-8aee-494b-a3a9-520ede27bb4c");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '9a0d7680-8aee-494b-a3a9-520ede27bb4c' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"bd022f38-6fed-47d1-8a77-e3d65bedff97":{"roots":{"references":[{"attributes":{},"id":"4354072f-9f71-4520-a920-5bd3bac1bf8c","type":"BasicTicker"},{"attributes":{"bottom":{"value":0},"fill_alpha":{"value":0.1},"fill_color":{"value":"#1f77b4"},"left":{"field":"left"},"line_alpha":{"value":0.1},"line_color":{"value":"#1f77b4"},"right":{"field":"right"},"top":{"field":"top"}},"id":"d6a8da4c-c27d-45d3-bdb2-c806d055d1cc","type":"Quad"},{"attributes":{"plot":{"id":"2fb2b697-72de-482b-b3d8-22f4b323a98f","subtype":"Figure","type":"Plot"}},"id":"f062af8e-bdc2-4efc-8ede-affec7f8c515","type":"ZoomOutTool"},{"attributes":{"plot":{"id":"2fb2b697-72de-482b-b3d8-22f4b323a98f","subtype":"Figure","type":"Plot"}},"id":"d88bc111-ddad-481c-bee3-6080a0f0f229","type":"PanTool"},{"attributes":{"formatter":{"id":"724e8524-50dc-41db-b7a4-9529069614a8","type":"BasicTickFormatter"},"plot":{"id":"2fb2b697-72de-482b-b3d8-22f4b323a98f","subtype":"Figure","type":"Plot"},"ticker":{"id":"162b8027-fb7e-4154-8fba-c4995f9ab2ac","type":"BasicTicker"}},"id":"d791c68b-30b3-4b1d-b1eb-eade2c220aed","type":"LinearAxis"},{"attributes":{"callback":null},"id":"acc9a98a-fd38-4141-b56d-9b5e86397ff0","type":"DataRange1d"},{"attributes":{"plot":null,"text":"Intervals between frame-on triggers (us)"},"id":"2a2ccf7c-4d7a-40e8-a47d-306ec83e3597","type":"Title"},{"attributes":{"formatter":{"id":"580fe194-2529-4585-8515-a6ec7989ea20","type":"BasicTickFormatter"},"plot":{"id":"2fb2b697-72de-482b-b3d8-22f4b323a98f","subtype":"Figure","type":"Plot"},"ticker":{"id":"4354072f-9f71-4520-a920-5bd3bac1bf8c","type":"BasicTicker"}},"id":"b9376381-07d3-402a-9231-e8dfa3d1b5db","type":"LinearAxis"},{"attributes":{},"id":"580fe194-2529-4585-8515-a6ec7989ea20","type":"BasicTickFormatter"},{"attributes":{"dimension":1,"plot":{"id":"2fb2b697-72de-482b-b3d8-22f4b323a98f","subtype":"Figure","type":"Plot"},"ticker":{"id":"4354072f-9f71-4520-a920-5bd3bac1bf8c","type":"BasicTicker"}},"id":"d49500b4-434c-4de4-b325-33e65b5d096e","type":"Grid"},{"attributes":{"callback":null,"column_names":["right","top","left"],"data":{"left":{"__ndarray__":"...","dtype":"float64","shape":[5000]},"right":{"__ndarray__":"...","dtype":"float64","shape":[5000]},"top":{"__ndarray__":"...","dtype":"float64","shape":[5000]}}},"id":"b4826d34-d9dc-4cd2-9399-d8adcc10b98b","type":"ColumnDataSource"},{"attributes":{},"id":"c1dc753e-9218-4a13-88a6-5ef5394b75b3","type":"ToolEvents"},{"attributes":{},"id":"724e8524-50dc-41db-b7a4-9529069614a8","type":"BasicTickFormatter"},{"attributes":{"plot":{"id":"2fb2b697-72de-482b-b3d8-22f4b323a98f","subtype":"Figure","type":"Plot"}},"id":"4c93a4fc-6469-4358-85fd-ff724762d140","type":"ZoomInTool"},{"attributes":{},"id":"162b8027-fb7e-4154-8fba-c4995f9ab2ac","type":"BasicTicker"},{"attributes":{"background_fill_color":{"value":"white"},"below":[{"id":"d791c68b-30b3-4b1d-b1eb-eade2c220aed","type":"LinearAxis"}],"left":[{"id":"b9376381-07d3-402a-9231-e8dfa3d1b5db","type":"LinearAxis"}],"renderers":[{"id":"d791c68b-30b3-4b1d-b1eb-eade2c220aed","type":"LinearAxis"},{"id":"f526ea9e-0b0d-4005-84c8-136a9d2d1d05","type":"Grid"},{"id":"b9376381-07d3-402a-9231-e8dfa3d1b5db","type":"LinearAxis"},{"id":"d49500b4-434c-4de4-b325-33e65b5d096e","type":"Grid"},{"id":"f5a0ea43-66c0-49a9-bcab-8f40382b8f85","type":"GlyphRenderer"}],"title":{"id":"2a2ccf7c-4d7a-40e8-a47d-306ec83e3597","type":"Title"},"tool_events":{"id":"c1dc753e-9218-4a13-88a6-5ef5394b75b3","type":"ToolEvents"},"toolbar":{"id":"5d682d0a-3f81-491e-94d4-d2bba1b7b3f4","type":"Toolbar"},"x_range":{"id":"acc9a98a-fd38-4141-b56d-9b5e86397ff0","type":"DataRange1d"},"y_range":{"id":"8e0c7276-386f-46ef-a446-81b0ddd00e31","type":"DataRange1d"}},"id":"2fb2b697-72de-482b-b3d8-22f4b323a98f","subtype":"Figure","type":"Plot"},{"attributes":{"plot":{"id":"2fb2b697-72de-482b-b3d8-22f4b323a98f","subtype":"Figure","type":"Plot"}},"id":"9970fca9-8e39-4205-b651-89cda5830730","type":"SaveTool"},{"attributes":{"active_drag":"auto","active_scrol ...

# %%
offs = [i for i,v in enumerate(tmp_ard_evs) if v[0]==0]
print len(offs)
off_times = [tmp_ard_evs[e][1] for e in offs]
off_intervals = np.diff(off_times)[0:100]
print min(off_intervals)
print max(off_intervals)
# Out:
# 103036
# 976
# 1196

# %%
#tmp_onset_idxs = np.where(np.diff([e[0] for e in ard_evs]) > 0)[0]   # where trigger val changes from 0-->1
#tmp_triggers = [e[0] for e in ard_evs]
on_val = 1
off_val = 0
tmp_onset_idxs = np.where(np.diff([e[0] for e in tmp_ard_evs]) > off_val)[0]  # onsets are where trigger val changes from 0-->1
first_onset_idx = tmp_onset_idxs[0]+1                               # Get first SI frame-trigger event
ard_evs = tmp_ard_evs[first_onset_idx:]                                  # Get rid of extra junk at start before DI trigger from SI
start_idx = 0 #copy.copy(first_onset_idx)
print ard_evs[start_idx]

frame_trigger_evs = []
frame_idxs = []
while start_idx < len(ard_evs)-1:
    found_new_frames = False
    curr_chunk = ard_evs[start_idx:start_idx+20]
    try:
        next_offset_ev = next(off for off in curr_chunk if off[0]==off_val)
        next_onset_ev = next(on for on in curr_chunk if on[0]==on_val and on[1]>next_offset_ev[1])
        found_off_idx = [i[1] for i in ard_evs].index(next_offset_ev[1])
        last_found_idx = [i[1] for i in ard_evs].index(next_onset_ev[1])
        frame_trigger_evs.append([ard_evs[start_idx], next_offset_ev])
        frame_idxs.append((start_idx, found_off_idx))
        start_idx = last_found_idx
        found_new_frame=True
    except StopIteration:
        print "No more triggers."
        if found_new_frame is True:  # No offset found
            print "last start idx: ", start_idx
        break
# Out:
# [1, 69919972]
# No more triggers.
# last start idx:  24713

# %%
print "current ON ev: ", ard_evs[start_idx] 
print "next offset ev: ", next_offset_ev
print "next onset ev: ", next_onset_ev
print frame_trigger_evs[-1]
if ard_evs[start_idx][1] > frame_trigger_evs[-1][1][1]:
    print "Appending last on-off pair."
    frame_trigger_evs.append([ard_evs[start_idx], next_offset_ev])
# Out:
# current ON ev:  [1, 100151156]
# next offset ev:  [0, 100149880]
# next onset ev:  [1, 100151156]
# [[1, 100139680], [0, 100149880]]
# Appending last on-off pair.

# %%
all_frame_trigger_evs = [val for sublist in frame_trigger_evs for val in sublist]
print "N fr trigger events: ", len(frame_trigger_evs)
print "N total trigger events: ", len(all_frame_trigger_evs)
print frame_trigger_evs[0:5]
5873*2
# Out:
# N fr trigger events:  2317
# N total trigger events:  4634
# [[[1, 69919972], [0, 69930680]], [[1, 69931872], [0, 69942580]], [[1, 69943772], [0, 69954480]], [[1, 69955672], [0, 69966380]], [[1, 69967572], [0, 69988992]]]
# 11746

# %%
n_expected_triggers = (1./session_info['target_freq'])*session_info['ncycles']*frame_rate*len(trigger_times)
print "Frame rate: ", frame_rate
print "N on-off pairs found:", len(frame_trigger_evs)
print "Expected {0:.2f} frame triggers. Missing {missed} triggers.".format(n_expected_triggers, missed=round(n_expected_triggers)-len(frame_trigger_evs)*2.)
# Out:
# Frame rate:  44.63
# N on-off pairs found: 2317
# Expected 13223.70 frame triggers. Missing 8590.0 triggers.

# %%
frame_trigger_evs[0][0]
# Out:
# [1, 69919972]

# %%
# PLOT time between each frame:
frame_intervals = np.diff([fr[0][1] for fr in frame_trigger_evs])
print "N intervals:", len(frame_intervals)
print "min:", min(frame_intervals)
print "max:", max(frame_intervals)
frame_high = (1/frame_rate)*1E6
print "frame dur: ", framedur

wiggle_room = 200 # time in us that we expect variation
misses = [i for i,v in enumerate(frame_intervals) if v>frame_high+200]
print "Skipped off triggers on %i frames." % len(misses)
p1 = figure(title="Intervals between frame-on triggers (us)",tools="save, zoom_in, zoom_out, pan",
            background_fill_color="white")

hist, edges = np.histogram(frame_intervals, density=True, bins=5000)
p1.quad(top=hist, bottom=0, left=edges[:-1], right=edges[1:],
        fill_color="#036564", line_color="#033649")
show(p1)
# Out:
# N intervals: 2316
# min: 10704
# max: 24312
# frame dur:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-25-38c55984dc42> in <module>()
#       5 print "max:", max(frame_intervals)
#       6 frame_high = (1/frame_rate)*1E6
# ----> 7 print "frame dur: ", framedur
#       8
#       9 wiggle_room = 200 # time in us that we expect variation
#
# NameError: name 'framedur' is not defined

# %%
print "misses:", misses[0:10]
print frame_trigger_evs[misses[0]]
missed_idx = misses[0]

# Find the corresponding frame-start index from the full list of arduiono-frame-events.
# Since an OFF trigger was missed, there will be many more "frame HIGH" events between a given
# missed-trigger index and it's corresponding next-found OFF index.
ard_idx_start = [ard[1] for ard in ard_evs].index(frame_trigger_evs[missed_idx][0][1])
curr_ard_chunk = ard_evs[ard_idx_start:ard_idx_start+40]
print curr_ard_chunk
# Out:
# misses: [30, 36, 42, 48, 54, 60, 107, 113, 119, 125]
# [[1, 13006636], [0, 13028056]]
# [[1, 13006636], [1, 13007828], [1, 13009016], [1, 13010208], [1, 13011396], [1, 13012588], [1, 13013776], [1, 13014968], [1, 13016156], [1, 13017348], [1, 13018536], [1, 13019728], [1, 13020916], [1, 13022108], [1, 13023296], [1, 13024488], [1, 13025676], [1, 13026868], [0, 13028056], [1, 13029248], [1, 13030436], [1, 13031628], [1, 13032816], [1, 13034008], [1, 13035196], [1, 13036388], [1, 13037584], [1, 13038768], [0, 13039956], [1, 13041148], [1, 13042336], [1, 13043528], [1, 13044716], [1, 13045908], [1, 13047096], [1, 13048288], [1, 13049476], [1, 13050668], [0, 13051856], [1, 13053048]]

# %%
13041148 - 13029248
13053048-13041148
# Out:
# 11900

# %%
np.diff([i[1] for i in curr_ard_chunk])
# Out:
# array([1192, 1188, 1192, 1188, 1192, 1188, 1192, 1188, 1192, 1188, 1192,
#        1188, 1192, 1188, 1192, 1188, 1192, 1188, 1192, 1188, 1192, 1188,
#        1192, 1188, 1192, 1196, 1184, 1188, 1192, 1188, 1192, 1188, 1192,
#        1188, 1192, 1188, 1192, 1188, 1192])

# %%
idx_in_ardevs = [fr[1] for fr in ard_evs].index(frame_on_evs[30][1])
idx_in_frevs = [fr[1] for fr in frame_trigger_evs].index(frame_on_evs[30][1])
print ard_evs[idx_in_ardevs]
print frame_trigger_evs[idx_in_frevs]
print ard_evs[idx_in_ardevs-1:idx_in_ardevs+40]
# print frame_trigger_evs[idx_in_frevs-1:idx_in_frevs+10]
# Out:
# [1, 13006636]
# [1, 13006636]
# [[0, 13005448], [1, 13006636], [1, 13007828], [1, 13009016], [1, 13010208], [1, 13011396], [1, 13012588], [1, 13013776], [1, 13014968], [1, 13016156], [1, 13017348], [1, 13018536], [1, 13019728], [1, 13020916], [1, 13022108], [1, 13023296], [1, 13024488], [1, 13025676], [1, 13026868], [0, 13028056], [1, 13029248], [1, 13030436], [1, 13031628], [1, 13032816], [1, 13034008], [1, 13035196], [1, 13036388], [1, 13037584], [1, 13038768], [0, 13039956], [1, 13041148], [1, 13042336], [1, 13043528], [1, 13044716], [1, 13045908], [1, 13047096], [1, 13048288], [1, 13049476], [1, 13050668], [0, 13051856], [1, 13053048]]

# %%
frame_high
# Out:
# 11745.360582569885

# %%
print frame_on_evs[30]
print frame_on_evs[30][1] + np.floor(frame_high)
ard_evs[idx_in_ardevs:idx_in_ardevs+20]
# Out:
# [1, 13006636]
# 13018381.0
# 155.0
# -1033.0
# 10708

# %%
on_tstamps = [t[1] for i,t in enumerate(tmp_ard_evs) if t[0]==1 and tmp_ard_evs[i-1][0]==0]
off_tstamps = [t[1] for i,t in enumerate(tmp_ard_evs) if t[0]==0 and tmp_ard_evs[i-1][0]==1]

on_idxs = [i+1 for i,val in enumerate(np.diff([i[0] for i in tmp_ard_evs])) if val==1]
off_idxs = [i+1 for i,val in enumerate(np.diff([i[0] for i in tmp_ard_evs])) if val==-1]
on_tstamps = [tmp_ard_evs[idx][1] for idx in on_idxs]
off_tstamps = [tmp_ard_evs[idx][1] for idx in off_idxs]

print "n on events: ", len(on_tstamps)
print "n off events:", len(off_tstamps)
for idx,(on,off) in enumerate(zip(on_tstamps, off_tstamps)):
    if on > off:
        print idx
        
#frame_durs = [off-on for on,off in zip(on_tstamps, off_tstamps)]
frame_intervals = np.diff(on_tstamps)
missing_between = [i for i in frame_intervals if i>15000]
print "frame high: ", frame_high

print len(missing_between)
print frame_intervals[0:100]
# Out:
# n on events:  11376
# n off events: 11376
# frame high:  11745.3605826

# %%
p1 = figure(title="Intervals between frame-on triggers (us)",tools="save, zoom_in, zoom_out, pan",
            background_fill_color="white")

hist, edges = np.histogram(np.array(np.diff(on_tstamps)), density=True, bins=5000)
p1.quad(top=hist, bottom=0, left=edges[:-1], right=edges[1:],
        fill_color="#036564", line_color="#033649")
show(p1)
# Out:
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="ac5eb65b-321b-49fc-a523-8be416119390"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         var el = document.getElementById("ac5eb65b-321b-49fc-a523-8be416119390");
#         el.textContent = "BokehJS " + Bokeh.version + " successfully loaded.";
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       try {
#         window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       }
#       finally {
#         delete window._bokeh_onload_callbacks
#       }
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("ac5eb65b-321b-49fc-a523-8be416119390");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid 'ac5eb65b-321b-49fc-a523-8be416119390' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"2c0bac7c-53a1-4335-bc27-e3dd6e848c95":{"roots":{"references":[{"attributes":{"callback":null},"id":"f79c255d-4832-4c0f-9b36-86f71b84b942","type":"DataRange1d"},{"attributes":{"formatter":{"id":"b65912bf-6249-47a9-abb0-802f724a72c1","type":"BasicTickFormatter"},"plot":{"id":"6c779938-c797-414a-9f94-53cc06f799e3","subtype":"Figure","type":"Plot"},"ticker":{"id":"623e14af-e721-4249-b364-208fdbcdbf28","type":"BasicTicker"}},"id":"989fd9eb-8f42-4709-92e9-4593121f4cc3","type":"LinearAxis"},{"attributes":{},"id":"650523f0-f945-4bba-9a81-b6ba7bd4b189","type":"LinearScale"},{"attributes":{},"id":"b65912bf-6249-47a9-abb0-802f724a72c1","type":"BasicTickFormatter"},{"attributes":{"data_source":{"id":"610500d7-f67b-4b1e-a6b0-b2072a176029","type":"ColumnDataSource"},"glyph":{"id":"ba56dd3c-30b2-484a-ba3c-d6f055e19499","type":"Quad"},"hover_glyph":null,"muted_glyph":null,"nonselection_glyph":{"id":"55960173-e2df-49a0-b9bf-1fef234b4119","type":"Quad"},"selection_glyph":null},"id":"1acc5504-0721-4f14-8eae-a7208d045032","type":"GlyphRenderer"},{"attributes":{},"id":"0e016d6f-b91a-4a63-927a-6ff44f56fcd6","type":"BasicTickFormatter"},{"attributes":{},"id":"623e14af-e721-4249-b364-208fdbcdbf28","type":"BasicTicker"},{"attributes":{"active_drag":"auto","active_inspect":"auto","active_scroll":"auto","active_tap":"auto","tools":[{"id":"8cd3cc75-fae5-4813-bcaf-f4f7510f7a21","type":"SaveTool"},{"id":"9cffec9d-7293-4956-a5c5-ba8c30863d04","type":"ZoomInTool"},{"id":"4cf25dcd-c912-46cd-a52b-e7551759256f","type":"ZoomOutTool"},{"id":"b6e3ff62-ca29-40de-8a05-a371d4012922","type":"PanTool"}]},"id":"a566c5dd-e088-46b8-b6a6-95c2643e72f3","type":"Toolbar"},{"attributes":{"bottom":{"value":0},"fill_color":{"value":"#036564"},"left":{"field":"left"},"line_color":{"value":"#033649"},"right":{"field":"right"},"top":{"field":"top"}},"id":"ba56dd3c-30b2-484a-ba3c-d6f055e19499","type":"Quad"},{"attributes":{"plot":{"id":"6c779938-c797-414a-9f94-53cc06f799e3","subtype":"Figure","type":"Plot"}},"id":"9cffec9d-7293-4956-a5c5-ba8c30863d04","type":"ZoomInTool"},{"attributes":{},"id":"86fd1221-a3a4-41a8-87f9-f5f0ca222b13","type":"BasicTicker"},{"attributes":{"plot":{"id":"6c779938-c797-414a-9f94-53cc06f799e3","subtype":"Figure","type":"Plot"}},"id":"b6e3ff62-ca29-40de-8a05-a371d4012922","type":"PanTool"},{"attributes":{"plot":{"id":"6c779938-c797-414a-9f94-53cc06f799e3","subtype":"Figure","type":"Plot"},"ticker":{"id":"86fd1221-a3a4-41a8-87f9-f5f0ca222b13","type":"BasicTicker"}},"id":"3cdfbc63-3f15-460d-8101-4a2f8a439ab1","type":"Grid"},{"attributes":{"plot":{"id":"6c779938-c797-414a-9f94-53cc06f799e3","subtype":"Figure","type":"Plot"}},"id":"4cf25dcd-c912-46cd-a52b-e7551759256f","type":"ZoomOutTool"},{"attributes":{"plot":null,"text":"Intervals between frame-on triggers (us)"},"id":"38888f18-91c0-407f-b40f-86db48813def","type":"Title"},{"attributes":{},"id":"b517c93a-4367-4bf2-8f80-ffba7dc23f6e","type":"ToolEvents"},{"attributes":{"dimension":1,"plot":{"id":"6c779938-c797-414a-9f94-53cc06f799e3","subtype":"Figure","type":"Plot"},"ticker":{"id":"623e14af-e721-4249-b364-208fdbcdbf28","type":"BasicTicker"}},"id":"6aa38ead-6bb2-493d-ba31-3b400d3a215e","type":"Grid"},{"attributes":{"callback":null},"id":"4e6d6f38-22c3-49fb-971c-ff064a747ad0","type":"DataRange1d"},{"attributes":{"background_fill_color":{"value":"white"},"below":[{"id":"60c5f21e-c487-4079-84ca-54a893605b6b","type":"LinearAxis"}],"left":[{"id":"989fd9eb-8f42-4709-92e9-4593121f4cc3","type":"LinearAxis"}],"renderers":[{"id":"60c5f21e-c487-4079-84ca-54a893605b6b","type":"LinearAxis"},{"id":"3cdfbc63-3f15-460d-8101-4a2f8a439ab1","type":"Grid"},{"id":"989fd9eb-8f42-4709-92e9-4593121f4cc3","type":"LinearAxis"},{"id":"6aa38ead-6bb2-493d-ba31-3b400d3a215e","type":"Grid"},{"id":"1acc5504-0721-4f14-8eae-a7208d045032","type":"GlyphRenderer"}],"title":{"id":"38888f18-91c0-407f-b40f-86db48813def","type":"Title"},"tool_events":{"id":"b517c93a-4367-4bf2-8f80-ffba7dc23f6e","type":"ToolEvents"},"tool ...

# %%
onset_idxs = [i+1 for i in tmp_onset_idxs]
tmp_offset_idxs = np.where(np.diff([e[0] for e in ard_evs]) < 0)[0]  # where trigger val changes from 1-->0
offset_idxs = [t+1 for t in tmp_offset_idxs]

if len(onset_idxs) != len(offset_idxs):
    print "N offsets %i does not match N onsets %i." % (len(offset_idxs), len(onset_idxs))
    #offsets.append(len(ard_evs)-1)
else:
    print "N offsets and onsets match! Found %i frame events." % len(onsets)

print "Expected {0:.2f} frame triggers. Missing {missed} triggers.".format(n_expected_triggers, missed=round(n_expected_triggers)-len(onset_idxs))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-214-eb6cca35dbf1> in <module>()
#       7     #offsets.append(len(ard_evs)-1)
#       8 else:
# ----> 9     print "N offsets and onsets match! Found %i frame events." % len(onsets)
#      10
#      11 print "Expected {0:.2f} frame triggers. Missing {missed} triggers.".format(n_expected_triggers, missed=round(n_expected_triggers)-len(onset_idxs))
#
# NameError: name 'onsets' is not defined

# %%
no_off_trigger = False
if ard_evs[-1][0]==1:
    no_off_trigger = True

# %%
offset_idxs = [a[1] for a in ard_evs if a[0]==0]
misses = [i for i,v in enumerate(np.diff(offset_idxs)[0:100]/1E3) if v>12]
print len(misses)
# Out:
# 42

# %%
# intervals = np.diff([i[1] for i in ard_evs])
intervals = np.diff([i[1] for i in ard_evs])
print len(intervals)
# Out:
# 132814

# %%
# PLOT intervals:
p1 = figure(title="Intervals between frame-on triggers (us)",tools="save, zoom_in, zoom_out, pan",
            background_fill_color="white")

#medintervals = np.array([i for i in intervals if i<=10000000])

hist, edges = np.histogram(intervals, density=True, bins=1000)
p1.quad(top=hist, bottom=0, left=edges[:-1], right=edges[1:],
        fill_color="#036564", line_color="#033649")
show(p1)
# Out:
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="8c368d30-6a93-4c1c-abc5-d43c4a0721ac"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         var el = document.getElementById("8c368d30-6a93-4c1c-abc5-d43c4a0721ac");
#         el.textContent = "BokehJS " + Bokeh.version + " successfully loaded.";
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       try {
#         window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       }
#       finally {
#         delete window._bokeh_onload_callbacks
#       }
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("8c368d30-6a93-4c1c-abc5-d43c4a0721ac");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '8c368d30-6a93-4c1c-abc5-d43c4a0721ac' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"ebf5b890-5587-4256-817e-f079e0e2a7e3":{"roots":{"references":[{"attributes":{},"id":"bc93638a-1464-456d-922d-e9be5976dbd4","type":"BasicTicker"},{"attributes":{"bottom":{"value":0},"fill_alpha":{"value":0.1},"fill_color":{"value":"#1f77b4"},"left":{"field":"left"},"line_alpha":{"value":0.1},"line_color":{"value":"#1f77b4"},"right":{"field":"right"},"top":{"field":"top"}},"id":"891356e5-236b-415f-a11d-7a77a8f2e8ca","type":"Quad"},{"attributes":{"data_source":{"id":"f2327563-1d59-49b9-b1b5-56911527ee87","type":"ColumnDataSource"},"glyph":{"id":"1c22655e-a1aa-4806-9a85-9504ae47a5eb","type":"Quad"},"hover_glyph":null,"muted_glyph":null,"nonselection_glyph":{"id":"891356e5-236b-415f-a11d-7a77a8f2e8ca","type":"Quad"},"selection_glyph":null},"id":"6a8a1213-3d63-4613-834e-df7f8db73fe2","type":"GlyphRenderer"},{"attributes":{},"id":"bd138315-0787-47e4-8b5a-f1e9c47e9411","type":"LinearScale"},{"attributes":{"formatter":{"id":"43c8c244-93bc-4196-bfb1-a0f6a922288c","type":"BasicTickFormatter"},"plot":{"id":"5a7330b7-7df1-4cce-99da-dd8afb96d7fe","subtype":"Figure","type":"Plot"},"ticker":{"id":"02e109e6-e04d-4b77-9814-3a7cfad786e3","type":"BasicTicker"}},"id":"b326709c-c275-451d-a192-abee8e02a7b1","type":"LinearAxis"},{"attributes":{"plot":{"id":"5a7330b7-7df1-4cce-99da-dd8afb96d7fe","subtype":"Figure","type":"Plot"}},"id":"c46b9de7-695d-44d8-b6d4-8a5c19e88407","type":"SaveTool"},{"attributes":{},"id":"02e109e6-e04d-4b77-9814-3a7cfad786e3","type":"BasicTicker"},{"attributes":{"bottom":{"value":0},"fill_color":{"value":"#036564"},"left":{"field":"left"},"line_color":{"value":"#033649"},"right":{"field":"right"},"top":{"field":"top"}},"id":"1c22655e-a1aa-4806-9a85-9504ae47a5eb","type":"Quad"},{"attributes":{"plot":null,"text":"Intervals between frame-on triggers (us)"},"id":"642af6fa-ee72-4061-b8f9-4ce049ce829a","type":"Title"},{"attributes":{"plot":{"id":"5a7330b7-7df1-4cce-99da-dd8afb96d7fe","subtype":"Figure","type":"Plot"}},"id":"8163a99f-df46-45e1-b126-8ef5f9d78ed3","type":"ZoomInTool"},{"attributes":{"background_fill_color":{"value":"white"},"below":[{"id":"70c8888b-7939-4828-837e-941d97d623db","type":"LinearAxis"}],"left":[{"id":"b326709c-c275-451d-a192-abee8e02a7b1","type":"LinearAxis"}],"renderers":[{"id":"70c8888b-7939-4828-837e-941d97d623db","type":"LinearAxis"},{"id":"7e8b6379-5150-45c1-a41b-817c1e88c0b2","type":"Grid"},{"id":"b326709c-c275-451d-a192-abee8e02a7b1","type":"LinearAxis"},{"id":"a0c87fc0-34a5-4e12-995d-bc66d18442f1","type":"Grid"},{"id":"6a8a1213-3d63-4613-834e-df7f8db73fe2","type":"GlyphRenderer"}],"title":{"id":"642af6fa-ee72-4061-b8f9-4ce049ce829a","type":"Title"},"tool_events":{"id":"8a4ef100-8547-4e9b-bd67-f83bd48da287","type":"ToolEvents"},"toolbar":{"id":"47e8a9c2-2a71-4216-88a1-0d5c1653b06f","type":"Toolbar"},"x_range":{"id":"636aaef8-8c7a-4eb0-be49-84886b255a36","type":"DataRange1d"},"x_scale":{"id":"3f7687f5-da81-4ac7-8c55-85ac391e58ba","type":"LinearScale"},"y_range":{"id":"e6b65455-e0e2-4c88-811b-86b5c3539928","type":"DataRange1d"},"y_scale":{"id":"bd138315-0787-47e4-8b5a-f1e9c47e9411","type":"LinearScale"}},"id":"5a7330b7-7df1-4cce-99da-dd8afb96d7fe","subtype":"Figure","type":"Plot"},{"attributes":{},"id":"3f7687f5-da81-4ac7-8c55-85ac391e58ba","type":"LinearScale"},{"attributes":{},"id":"cf9f575e-17a1-4e06-979b-47e12074a576","type":"BasicTickFormatter"},{"attributes":{"dimension":1,"plot":{"id":"5a7330b7-7df1-4cce-99da-dd8afb96d7fe","subtype":"Figure","type":"Plot"},"ticker":{"id":"02e109e6-e04d-4b77-9814-3a7cfad786e3","type":"BasicTicker"}},"id":"a0c87fc0-34a5-4e12-995d-bc66d18442f1","type":"Grid"},{"attributes":{"callback":null,"column_names":["right","top","left"],"data":{"left":{"__ndarray__":"...","dtype":"float64","shape":[1000]},"right":{"__ndarray__":"...","dtype":"float64","shape":[1000]},"top":{"__ndarray__":"...","dtype":"float64","shape":[1000]}}},"id":"f2327563-1d59-49b9-b1b5-56911527ee87","type":"ColumnDataSource"},{"attributes":{"plot":{"id":"5a7330b7-7df1-4cc ...

# %%
min(intervals)
# Out:
# 1172

# %%
tr_start_idx = onsets[0]
too_short = 500 #500 # if diff b/w offsets is < 100, interval is only 100*1500us = 150ms... 
on_intervals = np.where(np.diff(onsets) > too_short)[0] #[t for t in np.diff(onsets) if t>too_short]
#off_intervals = np.where(np.diff(offsets) > too_short)[0]

    new_file_idxs = [onsets[i+1] for i in on_intervals]
    new_file_idxs.append(tr_start_idx)
    new_file_idxs = sorted(new_file_idxs)
    new_file_markers = [ard_evs[i] for i in sorted(new_file_idxs)]

    end_file_idxs = []
    for i,nidx in enumerate(new_file_idxs[0:-1]):
        sublist = ard_evs[nidx:new_file_idxs[i+1]]
        last_off = np.where(np.diff([e[0] for e in sublist]) < 0)[0][-1]
        off_idx = nidx + last_off + 1
        end_file_idxs.append(off_idx)
    if no_off_trigger:
        end_file_idxs.append(len(ard_evs)-1) # just add the last trigger event for end-of-file
    else:
        sublist = ard_evs[onsets[-1]:] # Find all evs from last onset onward.
        final_trigger = np.where(np.diff([e[0] for e in sublist]) < 0)[0][0] # Find first off-trigger
        final_trigger_idx = onsets[-1] + final_trigger + 1 # add 2 to get actual off-trigger event after the 1st <0 difference found
        end_file_idxs.append(final_trigger_idx)

    end_file_markers = [ard_evs[i] for i in sorted(end_file_idxs)]
    print "Found %i TIF file chunks." % len(new_file_idxs)
    if len(new_file_markers)==1:
        print "DUR of session is: %f sec." % ((end_file_markers[0][1] - new_file_markers[0][1])/1E6)
    else:
        for midx in range(len(new_file_markers)):
            print "DUR of chunk is: %0.2f sec." % ((end_file_markers[midx][1] - new_file_markers[midx][1])/1E6)



    # # Plot to check file chunks
    # plt.plot([e[0] for e in evs], 'k*')
    # plt.plot(new_file_idxs, np.ones((1,len(new_file_idxs)))[0], 'g*', markersize=10)
    # plt.plot(end_file_idxs, np.ones((1,len(end_file_idxs)))[0], 'r*', markersize=10)
    # plt.title('Number of TIF files should be: %i' % len(new_file_markers))

# %%
    onset_evs = [ard_evs[on] for on in onsets]
    offset_evs = [ard_evs[off] for off in offsets]

# %%
    ard_acquisition_evs = []
    ard_frame_onset_times = []
    ard_frame_offset_times = []
    ard_onset_idxs = []
    ard_offset_idxs = []

    ard_file_durs = []
    ard_file_trigger_times = []
    ard_file_trigger_vals = []
    for sidx,eidx in zip(new_file_idxs, end_file_idxs):

        curr_acquisition_evs = ard_evs[sidx:eidx+1]
        ftimes = [e[1] for e in curr_acquisition_evs]

        curr_onset_evs = [ev for ev in onset_evs if ev[1]>=curr_acquisition_evs[0][1] and ev[1]<=curr_acquisition_evs[-1][1]]
        curr_offset_evs = [ev for ev in offset_evs if ev[1]>=curr_acquisition_evs[0][1] and ev[1]<=curr_acquisition_evs[-1][1]]

        curr_onset_times = [e[1] for e in curr_onset_evs]
        curr_offset_times = [e[1] for e in curr_offset_evs]

        curr_onset_idxs = [i for (i,ev) in enumerate(onset_evs) if ev[1]>=curr_acquisition_evs[0][1] and ev[1]<=curr_acquisition_evs[-1][1]]
        curr_offset_idxs = [i for (i,ev) in enumerate(offset_evs) if ev[1]>=curr_acquisition_evs[0][1] and ev[1]<=curr_acquisition_evs[-1][1]]


        frame_trigger_trange = (max(np.diff(curr_onset_times)) - min(np.diff(curr_onset_times))) / 1E3
        print "%i: Range of frame trigger time stamps: %0.2f - %0.2f ms." % (sidx, min(np.diff(curr_onset_times))/1E3, max(np.diff(curr_onset_times))/1E3)

        frame_durs = np.array(curr_offset_times) - np.array(curr_onset_times)

        ard_acquisition_evs.append(curr_acquisition_evs)
        ard_frame_onset_times.append(curr_onset_times)
        ard_frame_offset_times.append(curr_offset_times)
        ard_onset_idxs.append(curr_onset_idxs)
        ard_offset_idxs.append(curr_offset_idxs)


        ard_file_dur = (ard_times[eidx] - ard_times[sidx])/1E6
        ard_file_durs.append(ard_file_dur)

        ard_frame_tval = ard_codes[sidx:eidx+1]
        ard_frame_ttime = ard_times[sidx:eidx+1]
        ard_file_trigger_vals.append(ard_frame_tval)
        ard_file_trigger_times.append(ard_frame_ttime)
